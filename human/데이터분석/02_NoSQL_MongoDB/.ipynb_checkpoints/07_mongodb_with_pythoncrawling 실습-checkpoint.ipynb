# %% [markdown]
# ## **07 MongoDB with 파이썬 크롤링**

# %%
# !pip install bs4
# !pip install requests bs4
# Out:
# Collecting requests
#   Using cached requests-2.32.5-py3-none-any.whl.metadata (4.9 kB)
# Collecting bs4
#   Downloading bs4-0.0.2-py2.py3-none-any.whl.metadata (411 bytes)
# Collecting charset_normalizer<4,>=2 (from requests)
#   Using cached charset_normalizer-3.4.4-cp310-cp310-win_amd64.whl.metadata (38 kB)
# Collecting idna<4,>=2.5 (from requests)
#   Using cached idna-3.11-py3-none-any.whl.metadata (8.4 kB)
# Collecting urllib3<3,>=1.21.1 (from requests)
#   Using cached urllib3-2.6.1-py3-none-any.whl.metadata (6.6 kB)
# Collecting certifi>=2017.4.17 (from requests)
#   Using cached certifi-2025.11.12-py3-none-any.whl.metadata (2.5 kB)
# Collecting beautifulsoup4 (from bs4)
#   Using cached beautifulsoup4-4.14.3-py3-none-any.whl.metadata (3.8 kB)
# Collecting soupsieve>=1.6.1 (from beautifulsoup4->bs4)
#   Using cached soupsieve-2.8-py3-none-any.whl.metadata (4.6 kB)
# Collecting typing-extensions>=4.0.0 (from beautifulsoup4->bs4)
#   Using cached typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# Using cached requests-2.32.5-py3-none-any.whl (64 kB)
# Using cached charset_normalizer-3.4.4-cp310-cp310-win_amd64.whl (107 kB)
# Using cached idna-3.11-py3-none-any.whl (71 kB)
# Using cached urllib3-2.6.1-py3-none-any.whl (131 kB)
# Downloading bs4-0.0.2-py2.py3-none-any.whl (1.2 kB)
# Using cached certifi-2025.11.12-py3-none-any.whl (159 kB)
# Using cached beautifulsoup4-4.14.3-py3-none-any.whl (107 kB)
# Using cached soupsieve-2.8-py3-none-any.whl (36 kB)
# Using cached typing_extensions-4.15.0-py3-none-any.whl (44 kB)
# Installing collected packages: urllib3, typing-extensions, soupsieve, idna, charset_normalizer, certifi, requests, beautifulsoup4, bs4
#
#    ---------------------------------------- 0/9 [urllib3]
#    ---------------------------------------- 0/9 [urllib3]
#    ---------------------------------------- 0/9 [urllib3]
#    -------- ------------------------------- 2/9 [soupsieve]
#    -------- ------------------------------- 2/9 [soupsieve]
#    ------------- -------------------------- 3/9 [idna]
#    ----------------- ---------------------- 4/9 [charset_normalizer]
#    ----------------- ---------------------- 4/9 [charset_normalizer]
#    -------------------------- ------------- 6/9 [requests]
#    -------------------------- ------------- 6/9 [requests]
#    ------------------------------- -------- 7/9 [beautifulsoup4]
#    ------------------------------- -------- 7/9 [beautifulsoup4]
#    ----------------------------------- ---- 8/9 [bs4]
#    ---------------------------------------- 9/9 [bs4]
#
# Successfully installed beautifulsoup4-4.14.3 bs4-0.0.2 certifi-2025.11.12 charset_normalizer-3.4.4 idna-3.11 requests-2.32.5 soupsieve-2.8 typing-extensions-4.15.0 urllib3-2.6.1

# %%
import requests
from bs4 import BeautifulSoup

url = 'https://davelee-fun.github.io/'
response = requests.get(url)
html = response.content # html - > str 타입 
# print(response.text) html
print(type(html))
# Out:
# <class 'bytes'>

# %%
soup = BeautifulSoup(html,'html.parser') # 분석 가능한 객체로 변환
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1, shrink-to-fit=no" name="viewport"/>
# <link href="/assets/images/logo.png" rel="icon"/>
# <title>Home | Teddy의 선물 블로그</title>
# <!-- Begin Jekyll SEO tag v2.6.1 -->
# <title>Home | Teddy의 선물 블로그</title>
# <meta content="Jekyll v3.8.7" name="generator">
# <meta content="Home" property="og:title">
# <meta content="en_US" property="og:locale"/>
# <meta content="선물하기 좋은 선물을 고르고 골라서 소개하는 블로그입니다." name="description"/>
# <meta content="선물하기 좋은 선물을 고르고 골라서 소개하는 블로그입니다." property="og:description"/>
# <link href="https:///" rel="canonical">
# <meta content="https:///" property="og:url"/>
# <meta content="Teddy의 선물 블로그" property="og:site_name"/>
# <link href="https:///page2/" rel="next"/>
# <script type="application/ld+json">
# {"headline":"Home","@type":"WebSite","publisher":{"@type":"Organization","logo":{"@type":"ImageObject","url":"https:///assets/images/logo3.png"}},"url":"https:///","name":"Teddy의 선물 블로그","description":"선물하기 좋은 선물을 고르고 골라서 소개하는 블로그입니다.","@context":"https://schema.org"}</script>
# <!-- End Jekyll SEO tag -->
# <link crossorigin="anonymous" href="https://stackpath.bootstrapcdn.com/bootstrap/4.1.3/css/bootstrap.min.css" integrity="sha384-MCw98/SFnGE8fJT3GXwEOngsV7Zt27NXFoaoApmYm81iuXoPkFOJwJ8ERdknLPMO" rel="stylesheet"/>
# <link href="/assets/css/screen.css" rel="stylesheet"/>
# <link href="/assets/css/main.css" rel="stylesheet"/>
# <script src="/assets/js/jquery.min.js"></script>
# </link></meta></meta></head>
# <!-- change your GA id in _config.yml -->
# <script>
# (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
# (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
# m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
# })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
# ga('create', '', 'auto');
# ga('send', 'pageview');
# </script>
# <body class="layout-default">
# <!-- defer loading of font and font awesome -->
# <noscript id="deferred-styles">
# <link href="https://fonts.googleapis.com/css?family=Righteous%7CMerriweather:300,300i,400,400i,700,700i" rel="stylesheet"/>
# <link crossorigin="anonymous" href="https://use.fontawesome.com/releases/v5.0.13/css/all.css" integrity="sha384-DNOHZ68U8hZfKXOrtjWvjxusGo9WQnrNx2sqG0tfsghAvtVlRW3tvkXWZh58N9jp" rel="stylesheet"/>
# </noscript>
# <!-- Begin Menu Navigation
# ================================================== -->
# <nav class="navbar navbar-expand-lg navbar-light bg-white fixed-top mediumnavigation nav-down">
# <div class="container pr-0">
# <!-- Begin Logo -->
# <a class="navbar-brand" href="/">
# <img alt="Teddy의 선물 블로그" src="/assets/images/logo3.png"/>
# </a>
# <!-- End Logo -->
# <button aria-controls="navbarSupportedContent" aria-expanded="false" aria-label="Toggle navigation" class="navbar-toggler" data-target="#navbarMediumish" data-toggle="collapse" type="button">
# <span class="navbar-toggler-icon"></span>
# </button>
# <div class="collapse navbar-collapse" id="navbarMediumish">
# <!-- Begin Menu -->
# <ul class="navbar-nav ml-auto">
# <li class="nav-item active">
# <a class="nav-link" href="/index.html">Blog</a>
# </li>
# <li class="nav-item">
# <a class="nav-link" href="/about">About</a>
# </li>
# </ul>
# <!-- End Menu -->
# </div>
# </div>
# </nav>
# <!-- End Navigation
# ================================================== -->
# <div class="site-content">
# <div class="container">
# <!-- Site Title
# ================================================== -->
# <div class="mainheading">
# <h1 class="sitetitle">Teddy의 선물 블로그</h1>
# <p class="lead">
#         선물하기 좋은 선물을 고르고 골라서 소개하는 블로그입니다.
#     </p>
# </div>
# <!-- Content
# ================================================== -->
# <div class="main-content">
# <!-- Featured
# ================================================== -->
# <section class="featured-posts">
# <div class="section-title">
# <h2><span>Featured</span></h2>
# </div>
# <div class="row">
# <!-- begin post -->
# <div class="col-md-6 mb-30px">
# <div class="listfeaturedtag h-100">
# <div class="row h-100">
# <div class="col-12 col-md-12 col-lg-5 pr-lg-0">
# <div class="h-100">
# <div class="wrapthumbnail">
# <a href="/product-83/">
# <img class="featured-box-img-cover" src="https://static.coupangcdn.com/image/retail/images/2018/09/18/11/8/6964dd11-7ff2-448d-8462-db07e3ca2a5f.jpg"/>
# </a>
# </div>
# </div>
# </div>
# <div class="col-12 col-md-12 col-lg-7">
# <div class="h-100 card-group">
# <div class="card">
# <div class="card-body">
# <h2 class="card-title">
# <a class="text-dark" href="/product-83/">매트리스커버 관련 상품 추천</a>
# </h2>
# <h4 class="card-text">상품명: 보몽드 순면스퀘어 솔리드 누빔매트커버, 다크블루
#
# </h4>
# </div>
# <div class="card-footer b-0 bg-white mt-auto">
# <div class="wrapfooter">
# <span class="meta-footer-thumb">
# <img alt="Teddy" class="author-thumb" src="/assets/images/avatar.png"/>
# </span>
# <span class="author-meta">
# <span class="post-name"><a href="https://davelee-fun.github.io/class101/" target="_blank">Teddy</a></span><br/>
# <span class="post-date">05 Jun 2020</span>
# </span>
# <span class="post-read-more"><a href="//product-83/" title="Read Story"><svg class="svgIcon-use" height="25" viewbox="0 0 25 25" width="25"><path d="M19 6c0-1.1-.9-2-2-2H8c-1.1 0-2 .9-2 2v14.66h.012c.01.103.045.204.12.285a.5.5 0 0 0 .706.03L12.5 16.85l5.662 4.126a.508.508 0 0 0 .708-.03.5.5 0 0 0 .118-.285H19V6zm-6.838 9.97L7 19.636V6c0-.55.45-1 1-1h9c.55 0 1 .45 1 1v13.637l-5.162-3.668a.49.49 0 0 0-.676 0z" fill-rule="evenodd"></path></svg></a></span>
# <div class="clearfix"></div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <!-- end post -->
# <!-- begin post -->
# <div class="col-md-6 mb-30px">
# <div class="listfeaturedtag h-100">
# <div class="row h-100">
# <div class="col-12 col-md-12 col-lg-5 pr-lg-0">
# <div class="h-100">
# <div class="wrapthumbnail">
# <a href="/product-69/">
# <img class="featured-box-img-cover" src="https://static.coupangcdn.com/image/retail/images/2017/05/15/16/3/cd40fc67-e838-4f5d-b90a-45b0f0336729.jpg"/>
# </a>
# </div>
# </div>
# </div>
# <div class="col-12 col-md-12 col-lg-7">
# <div class="h-100 card-group">
# <div class="card">
# <div class="card-body">
# <h2 class="card-title">
# <a class="text-dark" href="/product-69/">여름이불세트 관련 상품 추천</a>
# </h2>
# <h4 class="card-text">상품명: 슈에뜨룸 선인장 리플 침구 세트, 베이지
#
# </h4>
# </div>
# <div class="card-footer b-0 bg-white mt-auto">
# <div class="wrapfooter">
# <span class="meta-footer-thumb">
# <img alt="Teddy" class="author-thumb" src="/assets/images/avatar.png"/>
# </span>
# <span class="author-meta">
# <span class="post-name"><a href="https://davelee-fun.github.io/class101/" target="_blank">Teddy</a></span><br/>
# <span class="post-date">05 Jun 2020</span>
# </span>
# <span class="post-read-more"><a href="//product-69/" title="Read Story"><svg class="svgIcon-use" height="25" viewbox="0 0 25 25" width="25"><path d="M19 6c0-1.1-.9-2-2-2H8c-1.1 0-2 .9-2 2v14.66h.012c.01.103.045.204.12.285a.5.5 0 0 0 .706.03L12.5 16.85l5.662 4.126a.508.508 0 0 0 .708-.03.5.5 0 0 0 .118-.285H19V6zm-6.838 9.97L7 19.636V6c0-.55.45-1 1-1h9c.55 0 1 .45 1 1v13.637l-5.162-3.668a.49.49 0 0 0-.676 0z" fill-rule="evenodd"></path></svg></a></span>
# <div class="clearfix"></div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <!-- end post -->
# <!-- begin post -->
# <div class="col-md-6 mb-30px">
# <div class="listfeaturedtag h-100">
# <div class="row h-100">
# <div class="col-12 col-md-12 col-lg-5 pr-lg-0">
# <div class="h-100">
# <div class="wrapthumbnail">
# <a href="/product-20/">
# <img class="featured-box-img-cover" src="https://static.coupangcdn.com/image/product/image/vendoritem/2015/10/16/3000156691/82761df2-59fb-4970-a67e-cea8bfcd8cac.jpg"/>
# </a>
# </div>
# </div>
# </div>
# <div class="col-12 col-md-12 col-lg-7">
# <div class="h-100 card-group">
# <div class="card">
# <div class="card-body">
# <h2 class="card-title">
# <a class="text-dark" href="/product-20/">행거도어 관련 상품 추천</a>
# </h2>
# <h4 class="card-text">상품명: 선우랜드 레인보우 2단 문걸이용 옷걸이 _중형, 화이트, 상세페이지참조
#
# </h4>
# </div>
# <div class="card-footer b-0 bg-white mt-auto">
# <div class="wrapfooter">
# <span class="meta-footer-thumb">
# <img alt="Teddy" class="author-thumb" src="/assets/images/avatar.png"/>
# </span>
# <span class="author-meta">
# <span class="post-name"><a href="https://davelee-fun.github.io/class101/" target="_blank">Teddy</a></span><br/>
# <span class="post-date">05 Jun 2020</span>
# </span>
# <span class="post-read-more"><a href="//product-20/" title="Read Story"><svg class="svgIcon-use" height="25" viewbox="0 0 25 25" width="25"><path d="M19 6c0-1.1-.9-2-2-2H8c-1.1 0-2 .9-2 2v14.66h.012c.01.103.045.204.12.285a.5.5 0 0 0 .706.03L12.5 16.85l5.662 4.126a.508.508 0 0 0 .708-.03.5.5 0 0 0 .118-.285H19V6zm-6.838 9.97L7 19.636V6c0-.55.45-1 1-1h9c.55 0 1 .45 1 1v13.637l-5.162-3.668a.49.49 0 0 0-.676 0z" fill-rule="evenodd"></path></svg></a></span>
# <div class="clearfix"></div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <!-- end post -->
# <!-- begin post -->
# <div class="col-md-6 mb-30px">
# <div class="listfeaturedtag h-100">
# <div class="row h-100">
# <div class="col-12 col-md-12 col-lg-5 pr-lg-0">
# <div class="h-100">
# <div class="wrapthumbnail">
# <a href="/product-105/">
# <img class="featured-box-img-cover" src="https://static.coupangcdn.com/image/retail/images/2020/02/25/12/2/a775b261-1ad7-4bad-873e-85ed4221f091.jpg"/>
# </a>
# </div>
# </div>
# </div>
# <div class="col-12 col-md-12 col-lg-7">
# <div class="h-100 card-group">
# <div class="card">
# <div class="card-body">
# <h2 class="card-title">
# <a class="text-dark" href="/product-105/">매트리스커버 관련 상품 추천</a>
# </h2>
# <h4 class="card-text">상품명: 보드래 헬로우 누빔 매트리스커버, 핑크
#
# </h4>
# </div>
# <div class="card-footer b-0 bg-white mt-auto">
# <div class="wrapfooter">
# <span class="meta-footer-thumb">
# <img alt="Teddy" class="author-thumb" src="/assets/images/avatar.png"/>
# </span>
# <span class="author-meta">
# <span class="post-name"><a href="https://davelee-fun.github.io/class101/" target="_blank">Teddy</a></span><br/>
# <span class="post-date">05 Jun 2020</span>
# </span>
# <span class="post-read-more"><a href="//product-105/" title="Read Story"><svg class="svgIcon-use" height="25" viewbox="0 0 25 25" width="25"><path d="M19 6c0-1.1-.9-2-2-2H8c-1.1 0-2 .9-2 2v14.66h.012c.01.103.045.204.12.285a.5.5 0 0 0 .706.03L12.5 16.85l5.662 4.126a.508.508 0 0 0 .708-.03.5.5 0 0 0 .118-.285H19V6zm-6.838 9.97L7 19.636V6c0-.55.45-1 1-1h9c.55 0 1 .45 1 1v13.637l-5.162-3.668a.49.49 0 0 0-.676 0z" fill-rule="evenodd"></path></svg></a></span>
# <div class="clearfix"></div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <!-- end post -->
# </div>
# </section>
# <!-- Posts Index
# ================================================== -->
# <section class="recent-posts">
# <div class="section-title">
# <h2><span>All Stories</span></h2>
# </div>
# <div class="row listrecent">
# <!-- begin post -->
# <div class="col-lg-4 col-md-6 mb-30px card-group">
# <div class="card h-100">
# <div class="maxthumb">
# <a href="/product-99/">
# <img alt="매트리스커버 관련 상품 추천" class="img-fluid" src="https://static.coupangcdn.com/image/retail/images/2017/10/11/16/6/bf3b2157-528d-4b24-9991-b601a24f4c6f.jpg"/>
# </a>
# </div>
# <div class="card-body">
# <h2 class="card-title">
# <a class="text-dark" href="/product-99/">매트리스커버 관련 상품 추천</a>
# </h2>
# <h4 class="card-text">상품명: 보드래 퍼펙트 누빔 매트리스커버, 차콜
#
# </h4>
# </div>
# <div class="card-footer bg-white">
# <div class="wrapfooter">
# <span class="meta-footer-thumb">
# <img alt="Teddy" class="author-thumb" src="/assets/images/avatar.png"/>
# </span>
# <span class="author-meta">
# <span class="post-name"><a href="https://davelee-fun.github.io/class101/" target="_blank">Teddy</a></span><br/>
# <span class="post-date">05 Jun 2020</span>
# </span>
# <span class="post-read-more"><a href="/product-99/" title="Read Story"><svg class="svgIcon-use" height="25" viewbox="0 0 25 25" width="25"><path d="M19 6c0-1.1-.9-2-2-2H8c-1.1 0-2 .9-2 2v14.66h.012c.01.103.045.204.12.285a.5.5 0 0 0 .706.03L12.5 16.85l5.662 4.126a.508.508 0 0 0 .708-.03.5.5 0 0 0 .118-.285H19V6zm-6.838 9.97L7 19.636V6c0-.55.45-1 1-1h9c.55 0 1 .45 1 1v13.637l-5.162-3.668a.49.49 0 0 0-.676 0z" fill-rule="evenodd"></path></svg></a></span>
# <div class="clearfix"></div>
# </div>
# </div>
# </div>
# </div>
# <!-- end post -->
# <!-- begin post -->
# <div class="col-lg-4 col-md-6 mb-30px card-group">
# <div class="card h-100">
# <div class="maxthumb">
# <a href="/product-98/">
# <img alt="매트리스커버 관련 상품 추천" class="img-fluid" src="https://static.coupangcdn.com/image/product/image/vendoritem/2018/11/28/3647689009/d72a996d-1e4e-42be-a23c-f9f6872214bb.jpg"/>
# </a>
# </div>
# <div class="card-body">
# <h2 class="card-title">
# <a class="text-dark" href="/product-98/">매트리스커버 관련 상품 추천</a>
# </h2>
# <h4 class="card-text">상품명: 피아블 클래식 방수 매트리스커버, 화이트
#
# </h4>
# </div>
# <div class="card-footer bg-white">
# <div class="wrapfooter">
# <span class="meta-footer-thumb">
# <img alt="Teddy" class="author-thumb" src="/assets/images/avatar.png"/>
# </span>
# <span class="author-meta">
# <span class="post-name"><a href="https://davelee-fun.github.io/class101/" target="_blank">Teddy</a></span><br/>
# <span class="post-date">05 Jun 2020</span>
# </span>
# <span class="post-read-more"><a href="/product-98/" title="Read Story"><svg class="svgIcon-use" height="25" viewbox="0 0 25 25" width="25"><path d="M19 6c0-1.1-.9-2-2-2H8c-1.1 0-2 .9-2 2v14.66h.012c.01.103.045.204.12.285a.5.5 0 0 0 .706.03L12.5 16.85l5.662 4.126a.508.508 0 0 0 .708-.03.5.5 0 0 0 .118-.285H19V6zm-6.838 9.97L7 19.636V6c0-.55.45-1 1-1h9c.55 0 1 .45 1 1v13.637l-5.162-3.668a.49.49 0 0 0-.676 0z" fill-rule="evenodd"></path></svg></a></span>
# <div class="clearfix"></div>
# </div>
# </div>
# </div>
# </div>
# <!-- end post -->
# <!-- begin post -->
# <div class="col-lg-4 col-md-6 mb-30px card-group">
# <div class="card h-100">
# <div class="maxthumb">
# <a href="/product-97/">
# <img alt="매트리스커버 관련 상품 추천" class="img-fluid" src="https://static.coupangcdn.com/image/product/image/vendoritem/2019/06/11/3361297461/699c49cc-5f9f-4927-ab26-b184f90c1571.jpg"/>
# </a>
# </div>
# <div class="card-body">
# <h2 class="card-title">
# <a class="text-dark" href="/product-97/">매트리스커버 관련 상품 추천</a>
# </h2>
# <h4 class="card-text">상품명: 더자리 에코항균 마이크로 매트리스커버, 밀키차콜그레이
#
# </h4>
# </div>
# <div class="card-footer bg-white">
# <div class="wrapfooter">
# <span class="meta-footer-thumb">
# <img alt="Teddy" class="author-thumb" src="/assets/images/avatar.png"/>
# </span>
# <span class="author-meta">
# <span class="post-name"><a href="https://davelee-fun.github.io/class101/" target="_blank">Teddy</a></span><br/>
# <span class="post-date">05 Jun 2020</span>
# </span>
# <span class="post-read-more"><a href="/product-97/" title="Read Story"><svg class="svgIcon-use" height="25" viewbox="0 0 25 25" width="25"><path d="M19 6c0-1.1-.9-2-2-2H8c-1.1 0-2 .9-2 2v14.66h.012c.01.103.045.204.12.285a.5.5 0 0 0 .706.03L12.5 16.85l5.662 4.126a.508.508 0 0 0 .708-.03.5.5 0 0 0 .118-.285H19V6zm-6.838 9.97L7 19.636V6c0-.55.45-1 1-1h9c.55 0 1 .45 1 1v13.637l-5.162-3.668a.49.49 0 0 0-.676 0z" fill-rule="evenodd"></path></svg></a></span>
# <div class="clearfix"></div>
# </div>
# </div>
# </div>
# </div>
# <!-- end post -->
# <!-- begin post -->
# <div class="col-lg-4 col-md-6 mb-30px card-group">
# <div class="card h-100">
# <div class="maxthumb">
# <a href="/product-96/">
# <img alt="매트리스커버 관련 상품 추천" class="img-fluid" src="https://static.coupangcdn.com/image/retail/images/2018/10/26/16/9/c6dfa004-442c-4f48-9ff1-b76d81bae046.jpg"/>
# </a>
# </div>
# <div class="card-body">
# <h2 class="card-title">
# <a class="text-dark" href="/product-96/">매트리스커버 관련 상품 추천</a>
# </h2>
# <h4 class="card-text">상품명: 더자리 프레쉬 퓨어 매트리스 커버, 퓨어 차콜그레이
#
# </h4>
# </div>
# <div class="card-footer bg-white">
# <div class="wrapfooter">
# <span class="meta-footer-thumb">
# <img alt="Teddy" class="author-thumb" src="/assets/images/avatar.png"/>
# </span>
# <span class="author-meta">
# <span class="post-name"><a href="https://davelee-fun.github.io/class101/" target="_blank">Teddy</a></span><br/>
# <span class="post-date">05 Jun 2020</span>
# </span>
# <span class="post-read-more"><a href="/product-96/" title="Read Story"><svg class="svgIcon-use" height="25" viewbox="0 0 25 25" width="25"><path d="M19 6c0-1.1-.9-2-2-2H8c-1.1 0-2 .9-2 2v14.66h.012c.01.103.045.204.12.285a.5.5 0 0 0 .706.03L12.5 16.85l5.662 4.126a.508.508 0 0 0 .708-.03.5.5 0 0 0 .118-.285H19V6zm-6.838 9.97L7 19.636V6c0-.55.45-1 1-1h9c.55 0 1 .45 1 1v13.637l-5.162-3.668a.49.49 0 0 0-.676 0z" fill-rule="evenodd"></path></svg></a></span>
# <div class="clearfix"></div>
# </div>
# </div>
# </div>
# </div>
# <!-- end post -->
# <!-- begin post -->
# <div class="col-lg-4 col-md-6 mb-30px card-group">
# <div class="card h-100">
# <div class="maxthumb">
# <a href="/product-95/">
# <img alt="매트리스커버 관련 상품 추천" class="img-fluid" src="https://static.coupangcdn.com/image/retail/images/2019/04/01/22/6/f9566f49-cf8c-48dd-bc73-b543a3f47f62.jpg"/>
# </a>
# </div>
# <div class="card-body">
# <h2 class="card-title">
# <a class="text-dark" href="/product-95/">매트리스커버 관련 상품 추천</a>
# </h2>
# <h4 class="card-text">상품명: 몽쉐어 알러스킨 항균 매트리스 커버, 카키그레이
#
# </h4>
# </div>
# <div class="card-footer bg-white">
# <div class="wrapfooter">
# <span class="meta-footer-thumb">
# <img alt="Teddy" class="author-thumb" src="/assets/images/avatar.png"/>
# </span>
# <span class="author-meta">
# <span class="post-name"><a href="https://davelee-fun.github.io/class101/" target="_blank">Teddy</a></span><br/>
# <span class="post-date">05 Jun 2020</span>
# </span>
# <span class="post-read-more"><a href="/product-95/" title="Read Story"><svg class="svgIcon-use" height="25" viewbox="0 0 25 25" width="25"><path d="M19 6c0-1.1-.9-2-2-2H8c-1.1 0-2 .9-2 2v14.66h.012c.01.103.045.204.12.285a.5.5 0 0 0 .706.03L12.5 16.85l5.662 4.126a.508.508 0 0 0 .708-.03.5.5 0 0 0 .118-.285H19V6zm-6.838 9.97L7 19.636V6c0-.55.45-1 1-1h9c.55 0 1 .45 1 1v13.637l-5.162-3.668a.49.49 0 0 0-.676 0z" fill-rule="evenodd"></path></svg></a></span>
# <div class="clearfix"></div>
# </div>
# </div>
# </div>
# </div>
# <!-- end post -->
# <!-- begin post -->
# <div class="col-lg-4 col-md-6 mb-30px card-group">
# <div class="card h-100">
# <div class="maxthumb">
# <a href="/product-94/">
# <img alt="매트리스커버 관련 상품 추천" class="img-fluid" src="https://static.coupangcdn.com/image/retail/images/12859794410743-0ab1b2fe-1cd4-4599-b38a-3fb22f3bf620.jpg"/>
# </a>
# </div>
# <div class="card-body">
# <h2 class="card-title">
# <a class="text-dark" href="/product-94/">매트리스커버 관련 상품 추천</a>
# </h2>
# <h4 class="card-text">상품명: 쿠팡 브랜드 - 코멧 홈 40수 트윌 순면 100% 홑겹 매트리스커버, 그레이
#
# </h4>
# </div>
# <div class="card-footer bg-white">
# <div class="wrapfooter">
# <span class="meta-footer-thumb">
# <img alt="Teddy" class="author-thumb" src="/assets/images/avatar.png"/>
# </span>
# <span class="author-meta">
# <span class="post-name"><a href="https://davelee-fun.github.io/class101/" target="_blank">Teddy</a></span><br/>
# <span class="post-date">05 Jun 2020</span>
# </span>
# <span class="post-read-more"><a href="/product-94/" title="Read Story"><svg class="svgIcon-use" height="25" viewbox="0 0 25 25" width="25"><path d="M19 6c0-1.1-.9-2-2-2H8c-1.1 0-2 .9-2 2v14.66h.012c.01.103.045.204.12.285a.5.5 0 0 0 .706.03L12.5 16.85l5.662 4.126a.508.508 0 0 0 .708-.03.5.5 0 0 0 .118-.285H19V6zm-6.838 9.97L7 19.636V6c0-.55.45-1 1-1h9c.55 0 1 .45 1 1v13.637l-5.162-3.668a.49.49 0 0 0-.676 0z" fill-rule="evenodd"></path></svg></a></span>
# <div class="clearfix"></div>
# </div>
# </div>
# </div>
# </div>
# <!-- end post -->
# <!-- begin post -->
# <div class="col-lg-4 col-md-6 mb-30px card-group">
# <div class="card h-100">
# <div class="maxthumb">
# <a href="/product-93/">
# <img alt="매트리스커버 관련 상품 추천" class="img-fluid" src="https://static.coupangcdn.com/image/retail/images/2019/03/28/19/3/2d9f9b52-0cc9-424f-8639-8f298429d244.jpg"/>
# </a>
# </div>
# <div class="card-body">
# <h2 class="card-title">
# <a class="text-dark" href="/product-93/">매트리스커버 관련 상품 추천</a>
# </h2>
# <h4 class="card-text">상품명: 패브릭아트 항균 마이크로 원단 매트리스 커버, 아이보리
#
# </h4>
# </div>
# <div class="card-footer bg-white">
# <div class="wrapfooter">
# <span class="meta-footer-thumb">
# <img alt="Teddy" class="author-thumb" src="/assets/images/avatar.png"/>
# </span>
# <span class="author-meta">
# <span class="post-name"><a href="https://davelee-fun.github.io/class101/" target="_blank">Teddy</a></span><br/>
# <span class="post-date">05 Jun 2020</span>
# </span>
# <span class="post-read-more"><a href="/product-93/" title="Read Story"><svg class="svgIcon-use" height="25" viewbox="0 0 25 25" width="25"><path d="M19 6c0-1.1-.9-2-2-2H8c-1.1 0-2 .9-2 2v14.66h.012c.01.103.045.204.12.285a.5.5 0 0 0 .706.03L12.5 16.85l5.662 4.126a.508.508 0 0 0 .708-.03.5.5 0 0 0 .118-.285H19V6zm-6.838 9.97L7 19.636V6c0-.55.45-1 1-1h9c.55 0 1 .45 1 1v13.637l-5.162-3.668a.49.49 0 0 0-.676 0z" fill-rule="evenodd"></path></svg></a></span>
# <div class="clearfix"></div>
# </div>
# </div>
# </div>
# </div>
# <!-- end post -->
# <!-- begin post -->
# <div class="col-lg-4 col-md-6 mb-30px card-group">
# <div class="card h-100">
# <div class="maxthumb">
# <a href="/product-92/">
# <img alt="매트리스커버 관련 상품 추천" class="img-fluid" src="https://static.coupangcdn.com/image/retail/images/2017/10/19/15/4/95b93d25-7014-458a-a2a5-9b93189cdcef.jpg"/>
# </a>
# </div>
# <div class="card-body">
# <h2 class="card-title">
# <a class="text-dark" href="/product-92/">매트리스커버 관련 상품 추천</a>
# </h2>
# <h4 class="card-text">상품명: 바숨 순면 누빔 침대 매트리스커버, 차콜
#
# </h4>
# </div>
# <div class="card-footer bg-white">
# <div class="wrapfooter">
# <span class="meta-footer-thumb">
# <img alt="Teddy" class="author-thumb" src="/assets/images/avatar.png"/>
# </span>
# <span class="author-meta">
# <span class="post-name"><a href="https://davelee-fun.github.io/class101/" target="_blank">Teddy</a></span><br/>
# <span class="post-date">05 Jun 2020</span>
# </span>
# <span class="post-read-more"><a href="/product-92/" title="Read Story"><svg class="svgIcon-use" height="25" viewbox="0 0 25 25" width="25"><path d="M19 6c0-1.1-.9-2-2-2H8c-1.1 0-2 .9-2 2v14.66h.012c.01.103.045.204.12.285a.5.5 0 0 0 .706.03L12.5 16.85l5.662 4.126a.508.508 0 0 0 .708-.03.5.5 0 0 0 .118-.285H19V6zm-6.838 9.97L7 19.636V6c0-.55.45-1 1-1h9c.55 0 1 .45 1 1v13.637l-5.162-3.668a.49.49 0 0 0-.676 0z" fill-rule="evenodd"></path></svg></a></span>
# <div class="clearfix"></div>
# </div>
# </div>
# </div>
# </div>
# <!-- end post -->
# <!-- begin post -->
# <div class="col-lg-4 col-md-6 mb-30px card-group">
# <div class="card h-100">
# <div class="maxthumb">
# <a href="/product-91/">
# <img alt="행거도어 관련 상품 추천" class="img-fluid" src="https://static.coupangcdn.com/image/retail/images/2019/07/29/12/3/704931d7-4dbd-4af7-9247-856831bdc61e.jpg"/>
# </a>
# </div>
# <div class="card-body">
# <h2 class="card-title">
# <a class="text-dark" href="/product-91/">행거도어 관련 상품 추천</a>
# </h2>
# <h4 class="card-text">상품명: WEMAX 다용도 문옷걸이, 화이트, 1개
#
# </h4>
# </div>
# <div class="card-footer bg-white">
# <div class="wrapfooter">
# <span class="meta-footer-thumb">
# <img alt="Teddy" class="author-thumb" src="/assets/images/avatar.png"/>
# </span>
# <span class="author-meta">
# <span class="post-name"><a href="https://davelee-fun.github.io/class101/" target="_blank">Teddy</a></span><br/>
# <span class="post-date">05 Jun 2020</span>
# </span>
# <span class="post-read-more"><a href="/product-91/" title="Read Story"><svg class="svgIcon-use" height="25" viewbox="0 0 25 25" width="25"><path d="M19 6c0-1.1-.9-2-2-2H8c-1.1 0-2 .9-2 2v14.66h.012c.01.103.045.204.12.285a.5.5 0 0 0 .706.03L12.5 16.85l5.662 4.126a.508.508 0 0 0 .708-.03.5.5 0 0 0 .118-.285H19V6zm-6.838 9.97L7 19.636V6c0-.55.45-1 1-1h9c.55 0 1 .45 1 1v13.637l-5.162-3.668a.49.49 0 0 0-.676 0z" fill-rule="evenodd"></path></svg></a></span>
# <div class="clearfix"></div>
# </div>
# </div>
# </div>
# </div>
# <!-- end post -->
# <!-- begin post -->
# <div class="col-lg-4 col-md-6 mb-30px card-group">
# <div class="card h-100">
# <div class="maxthumb">
# <a href="/product-90/">
# <img alt="매트리스커버 관련 상품 추천" class="img-fluid" src="https://static.coupangcdn.com/image/retail/images/2017/10/13/10/3/8379ffd3-63be-4da4-98f9-895aaa0c9b52.jpg"/>
# </a>
# </div>
# <div class="card-body">
# <h2 class="card-title">
# <a class="text-dark" href="/product-90/">매트리스커버 관련 상품 추천</a>
# </h2>
# <h4 class="card-text">상품명: 타카타카 프리미엄 나노 화이바 누빔 매트리스 커버, 젠틀핑핑
#
# </h4>
# </div>
# <div class="card-footer bg-white">
# <div class="wrapfooter">
# <span class="meta-footer-thumb">
# <img alt="Teddy" class="author-thumb" src="/assets/images/avatar.png"/>
# </span>
# <span class="author-meta">
# <span class="post-name"><a href="https://davelee-fun.github.io/class101/" target="_blank">Teddy</a></span><br/>
# <span class="post-date">05 Jun 2020</span>
# </span>
# <span class="post-read-more"><a href="/product-90/" title="Read Story"><svg class="svgIcon-use" height="25" viewbox="0 0 25 25" width="25"><path d="M19 6c0-1.1-.9-2-2-2H8c-1.1 0-2 .9-2 2v14.66h.012c.01.103.045.204.12.285a.5.5 0 0 0 .706.03L12.5 16.85l5.662 4.126a.508.508 0 0 0 .708-.03.5.5 0 0 0 .118-.285H19V6zm-6.838 9.97L7 19.636V6c0-.55.45-1 1-1h9c.55 0 1 .45 1 1v13.637l-5.162-3.668a.49.49 0 0 0-.676 0z" fill-rule="evenodd"></path></svg></a></span>
# <div class="clearfix"></div>
# </div>
# </div>
# </div>
# </div>
# <!-- end post -->
# <!-- begin post -->
# <div class="col-lg-4 col-md-6 mb-30px card-group">
# <div class="card h-100">
# <div class="maxthumb">
# <a href="/product-89/">
# <img alt="매트리스커버 관련 상품 추천" class="img-fluid" src="https://static.coupangcdn.com/image/retail/images/2018/09/17/19/4/329dbb2f-a0ad-44d4-af46-1eea0c548b67.jpg"/>
# </a>
# </div>
# <div class="card-body">
# <h2 class="card-title">
# <a class="text-dark" href="/product-89/">매트리스커버 관련 상품 추천</a>
# </h2>
# <h4 class="card-text">상품명: 보몽드 순면스퀘어 누빔매트커버, 다크그레이
#
# </h4>
# </div>
# <div class="card-footer bg-white">
# <div class="wrapfooter">
# <span class="meta-footer-thumb">
# <img alt="Teddy" class="author-thumb" src="/assets/images/avatar.png"/>
# </span>
# <span class="author-meta">
# <span class="post-name"><a href="https://davelee-fun.github.io/class101/" target="_blank">Teddy</a></span><br/>
# <span class="post-date">05 Jun 2020</span>
# </span>
# <span class="post-read-more"><a href="/product-89/" title="Read Story"><svg class="svgIcon-use" height="25" viewbox="0 0 25 25" width="25"><path d="M19 6c0-1.1-.9-2-2-2H8c-1.1 0-2 .9-2 2v14.66h.012c.01.103.045.204.12.285a.5.5 0 0 0 .706.03L12.5 16.85l5.662 4.126a.508.508 0 0 0 .708-.03.5.5 0 0 0 .118-.285H19V6zm-6.838 9.97L7 19.636V6c0-.55.45-1 1-1h9c.55 0 1 .45 1 1v13.637l-5.162-3.668a.49.49 0 0 0-.676 0z" fill-rule="evenodd"></path></svg></a></span>
# <div class="clearfix"></div>
# </div>
# </div>
# </div>
# </div>
# <!-- end post -->
# <!-- begin post -->
# <div class="col-lg-4 col-md-6 mb-30px card-group">
# <div class="card h-100">
# <div class="maxthumb">
# <a href="/product-88/">
# <img alt="매트리스커버 관련 상품 추천" class="img-fluid" src="https://static.coupangcdn.com/image/retail/images/339338956730835-5cbe0521-2a03-4fe2-8eb7-7a7ae9ff187f.jpg"/>
# </a>
# </div>
# <div class="card-body">
# <h2 class="card-title">
# <a class="text-dark" href="/product-88/">매트리스커버 관련 상품 추천</a>
# </h2>
# <h4 class="card-text">상품명: 보드래 국내산 순면 60수 누빔 매트리스커버, 그레이
#
# </h4>
# </div>
# <div class="card-footer bg-white">
# <div class="wrapfooter">
# <span class="meta-footer-thumb">
# <img alt="Teddy" class="author-thumb" src="/assets/images/avatar.png"/>
# </span>
# <span class="author-meta">
# <span class="post-name"><a href="https://davelee-fun.github.io/class101/" target="_blank">Teddy</a></span><br/>
# <span class="post-date">05 Jun 2020</span>
# </span>
# <span class="post-read-more"><a href="/product-88/" title="Read Story"><svg class="svgIcon-use" height="25" viewbox="0 0 25 25" width="25"><path d="M19 6c0-1.1-.9-2-2-2H8c-1.1 0-2 .9-2 2v14.66h.012c.01.103.045.204.12.285a.5.5 0 0 0 .706.03L12.5 16.85l5.662 4.126a.508.508 0 0 0 .708-.03.5.5 0 0 0 .118-.285H19V6zm-6.838 9.97L7 19.636V6c0-.55.45-1 1-1h9c.55 0 1 .45 1 1v13.637l-5.162-3.668a.49.49 0 0 0-.676 0z" fill-rule="evenodd"></path></svg></a></span>
# <div class="clearfix"></div>
# </div>
# </div>
# </div>
# </div>
# <!-- end post -->
# </div>
# </section>
# <!-- Pagination
# ================================================== -->
# <div class="bottompagination">
# <div class="pointerup"><i class="fa fa-caret-up"></i></div>
# <span class="navigation" role="navigation">
# <div class="pagination">
# <span>« Prev</span>
# <span class="ml-1 mr-1">1</span>
# <a class="ml-1 mr-1" href="/page2/">2</a>
# <a class="ml-1 mr-1" href="/page3/">3</a>
# <a class="ml-1 mr-1" href="/page4/">4</a>
# <a class="ml-1 mr-1" href="/page5/">5</a>
# <a class="ml-1 mr-1" href="/page6/">6</a>
# <a class="ml-1 mr-1" href="/page7/">7</a>
# <a class="ml-1 mr-1" href="/page8/">8</a>
# <a class="ml-1 mr-1" href="/page2/">Next »</a>
# </div>
# </span>
# </div>
# </div>
# <!-- Bottom Alert Bar
# ================================================== -->
# <div class="alertbar">
# <div class="container text-center">
# <span><img alt="Teddy의 선물 블로그" src="/assets/images/logo3.png"/>   Never miss a <b>story</b> from us, subscribe to our newsletter</span>
# <form action="https://wowthemes.us11.list-manage.com/subscribe/post?u=8aeb20a530e124561927d3bd8&amp;id=8c3d2d214b" class="wj-contact-form validate" method="post" name="mc-embedded-subscribe-form" novalidate="" target="_blank">
# <div class="mc-field-group">
# <input autocomplete="on" class="required email" id="mce-EMAIL" name="EMAIL" placeholder="Email" required="" type="email"/>
# <input class="heart" name="subscribe" type="submit" value="Subscribe"/>
# </div>
# </form>
# </div>
# </div>
# </div>
# <!-- Categories Jumbotron
# ================================================== -->
# <div class="jumbotron fortags">
# <div class="d-md-flex h-100">
# <div class="col-md-4 transpdark align-self-center text-center h-100">
# <div class="d-md-flex align-items-center justify-content-center h-100">
# <h2 class="d-md-block align-self-center py-1 font-weight-light">Explore <span class="d-none d-md-inline">→</span></h2>
# </div>
# </div>
# <div class="col-md-8 p-5 align-self-center text-center">
# <a class="mt-1 mb-1" href="/categories#가구/인테리어">가구/인테리어 (90)</a>
# </div>
# </div>
# </div>
# <!-- Begin Footer
# ================================================== -->
# <footer class="footer">
# <div class="container">
# <div class="row">
# <div class="col-md-6 col-sm-6 text-center text-lg-left">
#                 Copyright © 2020 Teddy의 선물 블로그
#             </div>
# <div class="col-md-6 col-sm-6 text-center text-lg-right">
# <a href="https://www.wowthemes.net/mediumish-free-jekyll-template/" target="_blank">Mediumish Jekyll Theme</a> by WowThemes.net
#             </div>
# </div>
# </div>
# </footer>
# <!-- End Footer
# ================================================== -->
# </div> <!-- /.site-content -->
# <!-- Scripts
# ================================================== -->
# <script crossorigin="anonymous" integrity="sha384-wHAiFfRlMFy6i5SRaxvfOCifBUQy1xHdJ/yoi7FRNXMRBu5WHdZYu1hA6ZOblgut" src="https://cdnjs.cloudflare.com/ajax/libs/popper.js/1.14.6/umd/popper.min.js"></script>
# <script crossorigin="anonymous" integrity="sha384-B0UglyR+jN6CkvvICOB2joaf5I4l3gm9GU6Hc1og6Ls7i6U/mkkaduKaBhlAXv9k" src="https://stackpath.bootstrapcdn.com/bootstrap/4.2.1/js/bootstrap.min.js"></script>
# <script src="/assets/js/mediumish.js"></script>
# <script src="/assets/js/ie10-viewport-bug-workaround.js"></script>
# </body>
# </html>

# %%
import requests
from bs4 import BeautifulSoup

for page_num in range(10):
    if page_num == 0:
        res = requests.get('https://davelee-fun.github.io/')
    else:
        res = requests.get('https://davelee-fun.github.io/page' + str(page_num + 1))
    soup = BeautifulSoup(res.content, 'html.parser')
    data = soup.select('div.card-body')
    for item in data:
        category = item.select_one('h2.card-title').get_text().replace('관련 상품 추천', '').strip()
        product = item.select_one('h4.card-text').get_text().replace('상품명:', '').strip()
        print (category, product)
# Out:
# 매트리스커버 보몽드 순면스퀘어 솔리드 누빔매트커버, 다크블루
# 여름이불세트 슈에뜨룸 선인장 리플 침구 세트, 베이지
# 행거도어 선우랜드 레인보우 2단 문걸이용 옷걸이 _중형, 화이트, 상세페이지참조
# 매트리스커버 보드래 헬로우 누빔 매트리스커버, 핑크
# 매트리스커버 보드래 퍼펙트 누빔 매트리스커버, 차콜
# 매트리스커버 피아블 클래식 방수 매트리스커버, 화이트
# 매트리스커버 더자리 에코항균 마이크로 매트리스커버, 밀키차콜그레이
# 매트리스커버 더자리 프레쉬 퓨어 매트리스 커버, 퓨어 차콜그레이
# 매트리스커버 몽쉐어 알러스킨 항균 매트리스 커버, 카키그레이
# 매트리스커버 쿠팡 브랜드 - 코멧 홈 40수 트윌 순면 100% 홑겹 매트리스커버, 그레이
# 매트리스커버 패브릭아트 항균 마이크로 원단 매트리스 커버, 아이보리
# 매트리스커버 바숨 순면 누빔 침대 매트리스커버, 차콜
# 행거도어 WEMAX 다용도 문옷걸이, 화이트, 1개
# 매트리스커버 타카타카 프리미엄 나노 화이바 누빔 매트리스 커버, 젠틀핑핑
# 매트리스커버 보몽드 순면스퀘어 누빔매트커버, 다크그레이
# 매트리스커버 보드래 국내산 순면 60수 누빔 매트리스커버, 그레이
# 매트리스커버 보드래 퍼펙트 누빔 매트리스커버, 베이지핑크
# 매트리스커버 쿠팡 브랜드 - 코멧 홈 40수 순면 누빔 매트리스커버, 챠콜
# 매트리스커버 바숨 순면 누빔 침대 매트리스커버, 화이트
# 매트리스커버 프랑떼 항균 방수 매트리스커버, 화이트
# 매트리스커버 보몽드 순면스퀘어 솔리드 누빔매트커버, 다크블루
# 매트리스커버 네이쳐리빙 피아블 클래식 방수 매트리스커버, 그레이
# 매트리스커버 쿠팡 브랜드 - 코멧 홈 순면 매트리스커버, 베이지
# 매트리스커버 타카타카 프리미엄 나노 화이바 누빔 매트리스 커버, 프렌치불독
# 매트리스커버 더자리 에코항균 마이크로 매트리스커버, 밀키그레이
# 매트리스커버 보몽드 순면스퀘어 누빔매트커버, 화이트
# 매트리스커버 피아블 클래식 방수 매트리스커버, 화이트
# 매트리스커버 쿠팡 브랜드 - 코멧 홈 순면 매트리스커버, 차콜그레이
# 여름이불세트 쉬즈홈 모던그리드 순면 여름이불 베개커버 패드세트, 핑크
# 여름이불세트 스코홈 빅리플 여름 차렵이불패드 3종 세트, 마린그레이
# 여름이불세트 아망떼 시어서커 리플 홑이불 패드세트, 웨이크
# 여름이불세트 마이센스 무더운 여름엔 시어서커 여름이불 패드 베개 이불세트 30종, 시어서커_파스텔그레이
# 여름이불세트 믹스앤매치 로라 프릴 시어서커 침구세트, 그레이
# 여름이불세트 에피소드1 샤베트 프릴 시어서커 여름이불패드세트, 그레이
# 여름이불세트 슈에뜨룸 선인장 리플 침구 세트, 베이지
# 여름이불세트 아망떼 시어서커 리플 홑이불 패드세트, 허브티
# 여름이불세트 지베딩 아이스베어 시어서커 여름침구 풀세트, 민트그레이
# 여름이불세트 쁘리엘르 테스 시어서커 여름이불 패드세트, 그레이
# 여름이불세트 쉬즈홈 시어서커 홑이불 + 토퍼 + 베개커버 세트, 나나 옐로우
# 여름이불세트 아망떼 시어서커 리플 퀼팅 이불패드세트, 리엔나
# 여름이불세트 바자르 트로피컬 인견 여름 이불세트 인견이불 + 베개커버 2p + 인견패드, 그린
# 여름이불세트 바자르 라이닝 혼방 인견 여름 이불베개세트 + 패드 Q, 쿨 네이비
# 여름이불세트 슈에뜨룸 비숑 피치스킨 침구세트, 그레이
# 여름이불세트 스코홈 시어서커 여름 이불 패드 3종 세트, 차콜
# 여름이불세트 스코홈 어번시리즈 순면 차렵이불 누빔 매트커버세트 S 차콜
# 여름이불세트 쉬즈홈 루즈 시어서커 차렵이불 패드세트, 그레이
# 여름이불세트 예가로드 메리엘 시어서커 누비이불 패드세트, 블루
# 여름이불세트 에피소드1 샤베트 프릴 시어서커 여름이불패드세트, 화이트
# 여름이불세트 쉬즈홈 플루 시어서커 차렵이불 패드세트, 그린
# 여름이불세트 메종 레이스 차렵 이불 세트, 블루
# 여름이불세트 믹스앤매치 로라 프릴 시어서커 침구세트, 그린
# 여름이불세트 슈에뜨룸 발그레 피치 리플 침구 세트, 혼합 색상
# 여름이불세트 보몽드 메종 레이스 차렵이불 3종 세트, 민트
# 여름이불세트 슈에뜨룸 체크 피치스킨 침구세트, 모카
# 여름이불세트 메리엘 시어서커 에어리플 이불세트, 그레이
# 여름이불세트 슈에뜨룸 빠삐용 시어서커 침구세트, 네이비
# 여름이불세트 믹스앤매치 에이프릴 리플 누비이불 패드세트, 화이트
# 여름이불세트 쉬즈홈 시어서커 홑이불 토퍼세트, 루즈 그레이
# 행거도어 이코디 5단 엔틱 도어 행거, 브라운, 1개
# 행거도어 선우랜드 우드볼 도어훅 4구, 실버, 1개
# 행거도어 리은상점 다용도 도어훅 문걸이 행거 모자걸이 머플러 목도리 걸이, 화이트, 5개
# 행거도어 퍼니스코 다용도걸이 모자걸이 가방걸이 도어훅 도어행거 문걸이, 엔틱브라운, 1세트
# 행거도어 스텐 도어후크 옷걸이/도어훅 문옷걸이 행거 바지걸이, 혼합 색상, 1개
# 행거도어 디비플러스 키펙스 컬러 폭조절 오버 도어훅, 블랙, 1개
# 행거도어 리빙스토리 1+1 문에 거는 문 옷걸이 음자리 도어후크 방문 행거, 음자리도어후크-로즈골드, 2개
# 행거도어 나이스후크 도어행거 2개 세트 (문행거), 블랙+화이트
# 행거도어 리빙파이 도어훅 옷걸이 행거 7구, 블랙, 1개
# 행거도어 선우랜드 우드볼 도어훅 10구, 실버, 1개
# 행거도어 웰렉스 도어행거 MH1060 신형 본사직발송 미니건조대 도어옷걸이 도어훅, 고동색, 1개
# 행거도어 엔비 엔틱 7구 도어훅 옷걸이, 도어훅 1+1, 1+1
# 행거도어 코시나 무타공 문걸이 후크선반 1단, 화이트, 1개
# 행거도어 코시나 무타공 올스텐 문걸이행거, 혼합 색상, 1개
# 행거도어 [아트박스 POOM/이케아] ENUDDEN 도어 행거, 본품, 수량
# 행거도어 비스비바 우드 폴 다용도걸이 3구, 혼합 색상, 1개
# 행거도어 숲속애 웨이브 도어후크 5구, 블랙, 1개
# 행거도어 펀타스틱 다용도 문틀걸이, 화이트, 1개
# 행거도어 선우랜드 우드볼 도어훅 4구, 화이트, 1개
# 행거도어 네이쳐리빙 어반모카 와이어 도어훅 옷걸이 6구, 단일 색상, 1개
# 행거도어 까사마루 블랑 접이식 문걸이 건조대, 1개
# 행거도어 선우랜드 우드볼 도어훅 6구, 실버, 1개
# 행거도어 이케아 ENUDDEN 문걸이 행거 402.516.66, 화이트, 1개
# 행거도어 선우랜드 우드볼 도어훅 10구, 화이트, 1개
# 행거도어 코멧 홈 우드볼 도어행거, 6구, 혼합색상
# 행거도어 선우랜드 레인보우 2단 문걸이용 옷걸이 _중형, 화이트, 상세페이지참조
# 행거도어 코시나 무타공 문걸이 후크선반 2단, 화이트, 1개
# 행거도어 스파이더락 도어후크 8구, 화이트, 1개
# 행거도어 선우랜드 우드볼 도어훅 6구, 화이트, 1개
# 행거도어 코멧 홈 우드볼 도어행거, 10구, 혼합색상
# 매트리스커버 보드래 헬로우 누빔 매트리스커버, 핑크
# 매트리스커버 보몽드 순면스퀘어 솔리드 누빔매트커버, 아이보리
# 매트리스커버 더자리 에코항균 마이크로 매트리스커버, 밀키핑크
# 매트리스커버 타카타카 프리미엄 나노 화이바 누빔 매트리스 커버, 미스밍고
# 매트리스커버 네이쳐리빙 피아블 클래식 방수 매트리스커버, 그레이
# 매트리스커버 프로텍트어베드 베이직 매트리스 방수커버, 그레이

# %% [markdown]
# ### Schema 구성 (필요 없음)

# %% [markdown]
# ### 크롤링 + MongoDB 저장

# %%
import requests
from bs4 import BeautifulSoup

for page_num in range(10):
    if page_num == 0:
        res = requests.get('https://davelee-fun.github.io/')
    else:
        res = requests.get('https://davelee-fun.github.io/page' + str(page_num + 1))
    soup = BeautifulSoup(res.content, 'html.parser')
    data = soup.select('div.card-body')
    for item in data:
        category = item.select_one('h2.card-title').get_text().replace('관련 상품 추천', '').strip()
        product = item.select_one('h4.card-text').get_text().replace('상품명:', '').strip()
        print (category, product)
# Out:
# 매트리스커버 보몽드 순면스퀘어 솔리드 누빔매트커버, 다크블루
# 여름이불세트 슈에뜨룸 선인장 리플 침구 세트, 베이지
# 행거도어 선우랜드 레인보우 2단 문걸이용 옷걸이 _중형, 화이트, 상세페이지참조
# 매트리스커버 보드래 헬로우 누빔 매트리스커버, 핑크
# 매트리스커버 보드래 퍼펙트 누빔 매트리스커버, 차콜
# 매트리스커버 피아블 클래식 방수 매트리스커버, 화이트
# 매트리스커버 더자리 에코항균 마이크로 매트리스커버, 밀키차콜그레이
# 매트리스커버 더자리 프레쉬 퓨어 매트리스 커버, 퓨어 차콜그레이
# 매트리스커버 몽쉐어 알러스킨 항균 매트리스 커버, 카키그레이
# 매트리스커버 쿠팡 브랜드 - 코멧 홈 40수 트윌 순면 100% 홑겹 매트리스커버, 그레이
# 매트리스커버 패브릭아트 항균 마이크로 원단 매트리스 커버, 아이보리
# 매트리스커버 바숨 순면 누빔 침대 매트리스커버, 차콜
# 행거도어 WEMAX 다용도 문옷걸이, 화이트, 1개
# 매트리스커버 타카타카 프리미엄 나노 화이바 누빔 매트리스 커버, 젠틀핑핑
# 매트리스커버 보몽드 순면스퀘어 누빔매트커버, 다크그레이
# 매트리스커버 보드래 국내산 순면 60수 누빔 매트리스커버, 그레이
# 매트리스커버 보드래 퍼펙트 누빔 매트리스커버, 베이지핑크
# 매트리스커버 쿠팡 브랜드 - 코멧 홈 40수 순면 누빔 매트리스커버, 챠콜
# 매트리스커버 바숨 순면 누빔 침대 매트리스커버, 화이트
# 매트리스커버 프랑떼 항균 방수 매트리스커버, 화이트
# 매트리스커버 보몽드 순면스퀘어 솔리드 누빔매트커버, 다크블루
# 매트리스커버 네이쳐리빙 피아블 클래식 방수 매트리스커버, 그레이
# 매트리스커버 쿠팡 브랜드 - 코멧 홈 순면 매트리스커버, 베이지
# 매트리스커버 타카타카 프리미엄 나노 화이바 누빔 매트리스 커버, 프렌치불독
# 매트리스커버 더자리 에코항균 마이크로 매트리스커버, 밀키그레이
# 매트리스커버 보몽드 순면스퀘어 누빔매트커버, 화이트
# 매트리스커버 피아블 클래식 방수 매트리스커버, 화이트
# 매트리스커버 쿠팡 브랜드 - 코멧 홈 순면 매트리스커버, 차콜그레이
# 여름이불세트 쉬즈홈 모던그리드 순면 여름이불 베개커버 패드세트, 핑크
# 여름이불세트 스코홈 빅리플 여름 차렵이불패드 3종 세트, 마린그레이
# 여름이불세트 아망떼 시어서커 리플 홑이불 패드세트, 웨이크
# 여름이불세트 마이센스 무더운 여름엔 시어서커 여름이불 패드 베개 이불세트 30종, 시어서커_파스텔그레이
# 여름이불세트 믹스앤매치 로라 프릴 시어서커 침구세트, 그레이
# 여름이불세트 에피소드1 샤베트 프릴 시어서커 여름이불패드세트, 그레이
# 여름이불세트 슈에뜨룸 선인장 리플 침구 세트, 베이지
# 여름이불세트 아망떼 시어서커 리플 홑이불 패드세트, 허브티
# 여름이불세트 지베딩 아이스베어 시어서커 여름침구 풀세트, 민트그레이
# 여름이불세트 쁘리엘르 테스 시어서커 여름이불 패드세트, 그레이
# 여름이불세트 쉬즈홈 시어서커 홑이불 + 토퍼 + 베개커버 세트, 나나 옐로우
# 여름이불세트 아망떼 시어서커 리플 퀼팅 이불패드세트, 리엔나
# 여름이불세트 바자르 트로피컬 인견 여름 이불세트 인견이불 + 베개커버 2p + 인견패드, 그린
# 여름이불세트 바자르 라이닝 혼방 인견 여름 이불베개세트 + 패드 Q, 쿨 네이비
# 여름이불세트 슈에뜨룸 비숑 피치스킨 침구세트, 그레이
# 여름이불세트 스코홈 시어서커 여름 이불 패드 3종 세트, 차콜
# 여름이불세트 스코홈 어번시리즈 순면 차렵이불 누빔 매트커버세트 S 차콜
# 여름이불세트 쉬즈홈 루즈 시어서커 차렵이불 패드세트, 그레이
# 여름이불세트 예가로드 메리엘 시어서커 누비이불 패드세트, 블루
# 여름이불세트 에피소드1 샤베트 프릴 시어서커 여름이불패드세트, 화이트
# 여름이불세트 쉬즈홈 플루 시어서커 차렵이불 패드세트, 그린
# 여름이불세트 메종 레이스 차렵 이불 세트, 블루
# 여름이불세트 믹스앤매치 로라 프릴 시어서커 침구세트, 그린
# 여름이불세트 슈에뜨룸 발그레 피치 리플 침구 세트, 혼합 색상
# 여름이불세트 보몽드 메종 레이스 차렵이불 3종 세트, 민트
# 여름이불세트 슈에뜨룸 체크 피치스킨 침구세트, 모카
# 여름이불세트 메리엘 시어서커 에어리플 이불세트, 그레이
# 여름이불세트 슈에뜨룸 빠삐용 시어서커 침구세트, 네이비
# 여름이불세트 믹스앤매치 에이프릴 리플 누비이불 패드세트, 화이트
# 여름이불세트 쉬즈홈 시어서커 홑이불 토퍼세트, 루즈 그레이
# 행거도어 이코디 5단 엔틱 도어 행거, 브라운, 1개
# 행거도어 선우랜드 우드볼 도어훅 4구, 실버, 1개
# 행거도어 리은상점 다용도 도어훅 문걸이 행거 모자걸이 머플러 목도리 걸이, 화이트, 5개
# 행거도어 퍼니스코 다용도걸이 모자걸이 가방걸이 도어훅 도어행거 문걸이, 엔틱브라운, 1세트
# 행거도어 스텐 도어후크 옷걸이/도어훅 문옷걸이 행거 바지걸이, 혼합 색상, 1개
# 행거도어 디비플러스 키펙스 컬러 폭조절 오버 도어훅, 블랙, 1개
# 행거도어 리빙스토리 1+1 문에 거는 문 옷걸이 음자리 도어후크 방문 행거, 음자리도어후크-로즈골드, 2개
# 행거도어 나이스후크 도어행거 2개 세트 (문행거), 블랙+화이트
# 행거도어 리빙파이 도어훅 옷걸이 행거 7구, 블랙, 1개
# 행거도어 선우랜드 우드볼 도어훅 10구, 실버, 1개
# 행거도어 웰렉스 도어행거 MH1060 신형 본사직발송 미니건조대 도어옷걸이 도어훅, 고동색, 1개
# 행거도어 엔비 엔틱 7구 도어훅 옷걸이, 도어훅 1+1, 1+1
# 행거도어 코시나 무타공 문걸이 후크선반 1단, 화이트, 1개
# 행거도어 코시나 무타공 올스텐 문걸이행거, 혼합 색상, 1개
# 행거도어 [아트박스 POOM/이케아] ENUDDEN 도어 행거, 본품, 수량
# 행거도어 비스비바 우드 폴 다용도걸이 3구, 혼합 색상, 1개
# 행거도어 숲속애 웨이브 도어후크 5구, 블랙, 1개
# 행거도어 펀타스틱 다용도 문틀걸이, 화이트, 1개
# 행거도어 선우랜드 우드볼 도어훅 4구, 화이트, 1개
# 행거도어 네이쳐리빙 어반모카 와이어 도어훅 옷걸이 6구, 단일 색상, 1개
# 행거도어 까사마루 블랑 접이식 문걸이 건조대, 1개
# 행거도어 선우랜드 우드볼 도어훅 6구, 실버, 1개
# 행거도어 이케아 ENUDDEN 문걸이 행거 402.516.66, 화이트, 1개
# 행거도어 선우랜드 우드볼 도어훅 10구, 화이트, 1개
# 행거도어 코멧 홈 우드볼 도어행거, 6구, 혼합색상
# 행거도어 선우랜드 레인보우 2단 문걸이용 옷걸이 _중형, 화이트, 상세페이지참조
# 행거도어 코시나 무타공 문걸이 후크선반 2단, 화이트, 1개
# 행거도어 스파이더락 도어후크 8구, 화이트, 1개
# 행거도어 선우랜드 우드볼 도어훅 6구, 화이트, 1개
# 행거도어 코멧 홈 우드볼 도어행거, 10구, 혼합색상
# 매트리스커버 보드래 헬로우 누빔 매트리스커버, 핑크
# 매트리스커버 보몽드 순면스퀘어 솔리드 누빔매트커버, 아이보리
# 매트리스커버 더자리 에코항균 마이크로 매트리스커버, 밀키핑크
# 매트리스커버 타카타카 프리미엄 나노 화이바 누빔 매트리스 커버, 미스밍고
# 매트리스커버 네이쳐리빙 피아블 클래식 방수 매트리스커버, 그레이
# 매트리스커버 프로텍트어베드 베이직 매트리스 방수커버, 그레이

# %% [markdown]
# ### MongoDB 데이터 읽기

# %%
from pymongo import MongoClient

# MongoDB에 연결 (인증 미필요시)
client = MongoClient("mongodb://localhost:27017")
# client = MongoClient("mongodb://username:password@localhost:27017")
# 인증이 필요하지 않은 경우 위의 첫 번째 줄 사용, 인증이 필요한 경우 두 번째 줄 사용

db = client['test'] # 'test' 데이터베이스 선택
collection = db.daveshop  # 'daveshop' 컬렉션 선택

documents = collection.find()  # 'users' 컬렉션의 모든 문서 조회
documents_list = document
for document in documents: # find() 의 결과는 iterable 객체이므로 반복문을 통해 각 데이터를 가져와야 함
    print(document)

# 연결 종료
# client.close()
# Out:
# {'_id': ObjectId('693a80a7dd56bb2de189e7c0'), 'category': '매트리스커버', 'product': '보몽드 순면스퀘어 솔리드 누빔매트커버, 다크블루'}
# {'_id': ObjectId('693a80a7dd56bb2de189e7c1'), 'category': '여름이불세트', 'product': '슈에뜨룸 선인장 리플 침구 세트, 베이지'}
# {'_id': ObjectId('693a80a7dd56bb2de189e7c2'), 'category': '행거도어', 'product': '선우랜드 레인보우 2단 문걸이용 옷걸이 _중형, 화이트, 상세페이지참조'}
# {'_id': ObjectId('693a80a7dd56bb2de189e7c3'), 'category': '매트리스커버', 'product': '보드래 헬로우 누빔 매트리스커버, 핑크'}
# {'_id': ObjectId('693a80a7dd56bb2de189e7c4'), 'category': '매트리스커버', 'product': '보드래 퍼펙트 누빔 매트리스커버, 차콜'}
# {'_id': ObjectId('693a80a7dd56bb2de189e7c5'), 'category': '매트리스커버', 'product': '피아블 클래식 방수 매트리스커버, 화이트'}
# {'_id': ObjectId('693a80a7dd56bb2de189e7c6'), 'category': '매트리스커버', 'product': '더자리 에코항균 마이크로 매트리스커버, 밀키차콜그레이'}
# {'_id': ObjectId('693a80a7dd56bb2de189e7c7'), 'category': '매트리스커버', 'product': '더자리 프레쉬 퓨어 매트리스 커버, 퓨어 차콜그레이'}
# {'_id': ObjectId('693a80a7dd56bb2de189e7c8'), 'category': '매트리스커버', 'product': '몽쉐어 알러스킨 항균 매트리스 커버, 카키그레이'}
# {'_id': ObjectId('693a80a7dd56bb2de189e7c9'), 'category': '매트리스커버', 'product': '쿠팡 브랜드 - 코멧 홈 40수 트윌 순면 100% 홑겹 매트리스커버, 그레이'}
# {'_id': ObjectId('693a80a7dd56bb2de189e7ca'), 'category': '매트리스커버', 'product': '패브릭아트 항균 마이크로 원단 매트리스 커버, 아이보리'}
# {'_id': ObjectId('693a80a7dd56bb2de189e7cb'), 'category': '매트리스커버', 'product': '바숨 순면 누빔 침대 매트리스커버, 차콜'}
# {'_id': ObjectId('693a80a7dd56bb2de189e7cc'), 'category': '행거도어', 'product': 'WEMAX 다용도 문옷걸이, 화이트, 1개'}
# {'_id': ObjectId('693a80a7dd56bb2de189e7cd'), 'category': '매트리스커버', 'product': '타카타카 프리미엄 나노 화이바 누빔 매트리스 커버, 젠틀핑핑'}
# {'_id': ObjectId('693a80a7dd56bb2de189e7ce'), 'category': '매트리스커버', 'product': '보몽드 순면스퀘어 누빔매트커버, 다크그레이'}
# {'_id': ObjectId('693a80a7dd56bb2de189e7cf'), 'category': '매트리스커버', 'product': '보드래 국내산 순면 60수 누빔 매트리스커버, 그레이'}
# {'_id': ObjectId('693a80a7dd56bb2de189e7d0'), 'category': '매트리스커버', 'product': '보드래 퍼펙트 누빔 매트리스커버, 베이지핑크'}
# {'_id': ObjectId('693a80a7dd56bb2de189e7d1'), 'category': '매트리스커버', 'product': '쿠팡 브랜드 - 코멧 홈 40수 순면 누빔 매트리스커버, 챠콜'}
# {'_id': ObjectId('693a80a7dd56bb2de189e7d2'), 'category': '매트리스커버', 'product': '바숨 순면 누빔 침대 매트리스커버, 화이트'}
# {'_id': ObjectId('693a80a7dd56bb2de189e7d3'), 'category': '매트리스커버', 'product': '프랑떼 항균 방수 매트리스커버, 화이트'}
# {'_id': ObjectId('693a80a7dd56bb2de189e7d4'), 'category': '매트리스커버', 'product': '보몽드 순면스퀘어 솔리드 누빔매트커버, 다크블루'}
# {'_id': ObjectId('693a80a7dd56bb2de189e7d5'), 'category': '매트리스커버', 'product': '네이쳐리빙 피아블 클래식 방수 매트리스커버, 그레이'}
# {'_id': ObjectId('693a80a7dd56bb2de189e7d6'), 'category': '매트리스커버', 'product': '쿠팡 브랜드 - 코멧 홈 순면 매트리스커버, 베이지'}
# {'_id': ObjectId('693a80a7dd56bb2de189e7d7'), 'category': '매트리스커버', 'product': '타카타카 프리미엄 나노 화이바 누빔 매트리스 커버, 프렌치불독'}
# {'_id': ObjectId('693a80a7dd56bb2de189e7d8'), 'category': '매트리스커버', 'product': '더자리 에코항균 마이크로 매트리스커버, 밀키그레이'}
# {'_id': ObjectId('693a80a7dd56bb2de189e7d9'), 'category': '매트리스커버', 'product': '보몽드 순면스퀘어 누빔매트커버, 화이트'}
# {'_id': ObjectId('693a80a7dd56bb2de189e7da'), 'category': '매트리스커버', 'product': '피아블 클래식 방수 매트리스커버, 화이트'}
# {'_id': ObjectId('693a80a7dd56bb2de189e7db'), 'category': '매트리스커버', 'product': '쿠팡 브랜드 - 코멧 홈 순면 매트리스커버, 차콜그레이'}
# {'_id': ObjectId('693a80a7dd56bb2de189e7dc'), 'category': '여름이불세트', 'product': '쉬즈홈 모던그리드 순면 여름이불 베개커버 패드세트, 핑크'}
# {'_id': ObjectId('693a80a7dd56bb2de189e7dd'), 'category': '여름이불세트', 'product': '스코홈 빅리플 여름 차렵이불패드 3종 세트, 마린그레이'}
# {'_id': ObjectId('693a80a7dd56bb2de189e7de'), 'category': '여름이불세트', 'product': '아망떼 시어서커 리플 홑이불 패드세트, 웨이크'}
# {'_id': ObjectId('693a80a7dd56bb2de189e7df'), 'category': '여름이불세트', 'product': '마이센스 무더운 여름엔 시어서커 여름이불 패드 베개 이불세트 30종, 시어서커_파스텔그레이'}
# {'_id': ObjectId('693a80a7dd56bb2de189e7e0'), 'category': '여름이불세트', 'product': '믹스앤매치 로라 프릴 시어서커 침구세트, 그레이'}
# {'_id': ObjectId('693a80a7dd56bb2de189e7e1'), 'category': '여름이불세트', 'product': '에피소드1 샤베트 프릴 시어서커 여름이불패드세트, 그레이'}
# {'_id': ObjectId('693a80a7dd56bb2de189e7e2'), 'category': '여름이불세트', 'product': '슈에뜨룸 선인장 리플 침구 세트, 베이지'}
# {'_id': ObjectId('693a80a7dd56bb2de189e7e3'), 'category': '여름이불세트', 'product': '아망떼 시어서커 리플 홑이불 패드세트, 허브티'}
# {'_id': ObjectId('693a80a7dd56bb2de189e7e4'), 'category': '여름이불세트', 'product': '지베딩 아이스베어 시어서커 여름침구 풀세트, 민트그레이'}
# {'_id': ObjectId('693a80a7dd56bb2de189e7e5'), 'category': '여름이불세트', 'product': '쁘리엘르 테스 시어서커 여름이불 패드세트, 그레이'}
# {'_id': ObjectId('693a80a7dd56bb2de189e7e6'), 'category': '여름이불세트', 'product': '쉬즈홈 시어서커 홑이불 + 토퍼 + 베개커버 세트, 나나 옐로우'}
# {'_id': ObjectId('693a80a7dd56bb2de189e7e7'), 'category': '여름이불세트', 'product': '아망떼 시어서커 리플 퀼팅 이불패드세트, 리엔나'}
# {'_id': ObjectId('693a80a8dd56bb2de189e7e8'), 'category': '여름이불세트', 'product': '바자르 트로피컬 인견 여름 이불세트 인견이불 + 베개커버 2p + 인견패드, 그린'}
# {'_id': ObjectId('693a80a8dd56bb2de189e7e9'), 'category': '여름이불세트', 'product': '바자르 라이닝 혼방 인견 여름 이불베개세트 + 패드 Q, 쿨 네이비'}
# {'_id': ObjectId('693a80a8dd56bb2de189e7ea'), 'category': '여름이불세트', 'product': '슈에뜨룸 비숑 피치스킨 침구세트, 그레이'}
# {'_id': ObjectId('693a80a8dd56bb2de189e7eb'), 'category': '여름이불세트', 'product': '스코홈 시어서커 여름 이불 패드 3종 세트, 차콜'}
# {'_id': ObjectId('693a80a8dd56bb2de189e7ec'), 'category': '여름이불세트', 'product': '스코홈 어번시리즈 순면 차렵이불 누빔 매트커버세트 S 차콜'}
# {'_id': ObjectId('693a80a8dd56bb2de189e7ed'), 'category': '여름이불세트', 'product': '쉬즈홈 루즈 시어서커 차렵이불 패드세트, 그레이'}
# {'_id': ObjectId('693a80a8dd56bb2de189e7ee'), 'category': '여름이불세트', 'product': '예가로드 메리엘 시어서커 누비이불 패드세트, 블루'}
# {'_id': ObjectId('693a80a8dd56bb2de189e7ef'), 'category': '여름이불세트', 'product': '에피소드1 샤베트 프릴 시어서커 여름이불패드세트, 화이트'}
# {'_id': ObjectId('693a80a8dd56bb2de189e7f0'), 'category': '여름이불세트', 'product': '쉬즈홈 플루 시어서커 차렵이불 패드세트, 그린'}
# {'_id': ObjectId('693a80a8dd56bb2de189e7f1'), 'category': '여름이불세트', 'product': '메종 레이스 차렵 이불 세트, 블루'}
# {'_id': ObjectId('693a80a8dd56bb2de189e7f2'), 'category': '여름이불세트', 'product': '믹스앤매치 로라 프릴 시어서커 침구세트, 그린'}
# {'_id': ObjectId('693a80a8dd56bb2de189e7f3'), 'category': '여름이불세트', 'product': '슈에뜨룸 발그레 피치 리플 침구 세트, 혼합 색상'}
# {'_id': ObjectId('693a80a8dd56bb2de189e7f4'), 'category': '여름이불세트', 'product': '보몽드 메종 레이스 차렵이불 3종 세트, 민트'}
# {'_id': ObjectId('693a80a8dd56bb2de189e7f5'), 'category': '여름이불세트', 'product': '슈에뜨룸 체크 피치스킨 침구세트, 모카'}
# {'_id': ObjectId('693a80a8dd56bb2de189e7f6'), 'category': '여름이불세트', 'product': '메리엘 시어서커 에어리플 이불세트, 그레이'}
# {'_id': ObjectId('693a80a8dd56bb2de189e7f7'), 'category': '여름이불세트', 'product': '슈에뜨룸 빠삐용 시어서커 침구세트, 네이비'}
# {'_id': ObjectId('693a80a8dd56bb2de189e7f8'), 'category': '여름이불세트', 'product': '믹스앤매치 에이프릴 리플 누비이불 패드세트, 화이트'}
# {'_id': ObjectId('693a80a8dd56bb2de189e7f9'), 'category': '여름이불세트', 'product': '쉬즈홈 시어서커 홑이불 토퍼세트, 루즈 그레이'}
# {'_id': ObjectId('693a80a8dd56bb2de189e7fa'), 'category': '행거도어', 'product': '이코디 5단 엔틱 도어 행거, 브라운, 1개'}
# {'_id': ObjectId('693a80a8dd56bb2de189e7fb'), 'category': '행거도어', 'product': '선우랜드 우드볼 도어훅 4구, 실버, 1개'}
# {'_id': ObjectId('693a80a8dd56bb2de189e7fc'), 'category': '행거도어', 'product': '리은상점 다용도 도어훅 문걸이 행거 모자걸이 머플러 목도리 걸이, 화이트, 5개'}
# {'_id': ObjectId('693a80a8dd56bb2de189e7fd'), 'category': '행거도어', 'product': '퍼니스코 다용도걸이 모자걸이 가방걸이 도어훅 도어행거 문걸이, 엔틱브라운, 1세트'}
# {'_id': ObjectId('693a80a8dd56bb2de189e7fe'), 'category': '행거도어', 'product': '스텐 도어후크 옷걸이/도어훅 문옷걸이 행거 바지걸이, 혼합 색상, 1개'}
# {'_id': ObjectId('693a80a8dd56bb2de189e7ff'), 'category': '행거도어', 'product': '디비플러스 키펙스 컬러 폭조절 오버 도어훅, 블랙, 1개'}
# {'_id': ObjectId('693a80a9dd56bb2de189e800'), 'category': '행거도어', 'product': '리빙스토리 1+1 문에 거는 문 옷걸이 음자리 도어후크 방문 행거, 음자리도어후크-로즈골드, 2개'}
# {'_id': ObjectId('693a80a9dd56bb2de189e801'), 'category': '행거도어', 'product': '나이스후크 도어행거 2개 세트 (문행거), 블랙+화이트'}
# {'_id': ObjectId('693a80a9dd56bb2de189e802'), 'category': '행거도어', 'product': '리빙파이 도어훅 옷걸이 행거 7구, 블랙, 1개'}
# {'_id': ObjectId('693a80a9dd56bb2de189e803'), 'category': '행거도어', 'product': '선우랜드 우드볼 도어훅 10구, 실버, 1개'}
# {'_id': ObjectId('693a80a9dd56bb2de189e804'), 'category': '행거도어', 'product': '웰렉스 도어행거 MH1060 신형 본사직발송 미니건조대 도어옷걸이 도어훅, 고동색, 1개'}
# {'_id': ObjectId('693a80a9dd56bb2de189e805'), 'category': '행거도어', 'product': '엔비 엔틱 7구 도어훅 옷걸이, 도어훅 1+1, 1+1'}
# {'_id': ObjectId('693a80a9dd56bb2de189e806'), 'category': '행거도어', 'product': '코시나 무타공 문걸이 후크선반 1단, 화이트, 1개'}
# {'_id': ObjectId('693a80a9dd56bb2de189e807'), 'category': '행거도어', 'product': '코시나 무타공 올스텐 문걸이행거, 혼합 색상, 1개'}
# {'_id': ObjectId('693a80a9dd56bb2de189e808'), 'category': '행거도어', 'product': '[아트박스 POOM/이케아] ENUDDEN 도어 행거, 본품, 수량'}
# {'_id': ObjectId('693a80a9dd56bb2de189e809'), 'category': '행거도어', 'product': '비스비바 우드 폴 다용도걸이 3구, 혼합 색상, 1개'}
# {'_id': ObjectId('693a80a9dd56bb2de189e80a'), 'category': '행거도어', 'product': '숲속애 웨이브 도어후크 5구, 블랙, 1개'}
# {'_id': ObjectId('693a80a9dd56bb2de189e80b'), 'category': '행거도어', 'product': '펀타스틱 다용도 문틀걸이, 화이트, 1개'}
# {'_id': ObjectId('693a80a9dd56bb2de189e80c'), 'category': '행거도어', 'product': '선우랜드 우드볼 도어훅 4구, 화이트, 1개'}
# {'_id': ObjectId('693a80a9dd56bb2de189e80d'), 'category': '행거도어', 'product': '네이쳐리빙 어반모카 와이어 도어훅 옷걸이 6구, 단일 색상, 1개'}
# {'_id': ObjectId('693a80a9dd56bb2de189e80e'), 'category': '행거도어', 'product': '까사마루 블랑 접이식 문걸이 건조대, 1개'}
# {'_id': ObjectId('693a80a9dd56bb2de189e80f'), 'category': '행거도어', 'product': '선우랜드 우드볼 도어훅 6구, 실버, 1개'}
# {'_id': ObjectId('693a80a9dd56bb2de189e810'), 'category': '행거도어', 'product': '이케아 ENUDDEN 문걸이 행거 402.516.66, 화이트, 1개'}
# {'_id': ObjectId('693a80a9dd56bb2de189e811'), 'category': '행거도어', 'product': '선우랜드 우드볼 도어훅 10구, 화이트, 1개'}
# {'_id': ObjectId('693a80a9dd56bb2de189e812'), 'category': '행거도어', 'product': '코멧 홈 우드볼 도어행거, 6구, 혼합색상'}
# {'_id': ObjectId('693a80a9dd56bb2de189e813'), 'category': '행거도어', 'product': '선우랜드 레인보우 2단 문걸이용 옷걸이 _중형, 화이트, 상세페이지참조'}
# {'_id': ObjectId('693a80a9dd56bb2de189e814'), 'category': '행거도어', 'product': '코시나 무타공 문걸이 후크선반 2단, 화이트, 1개'}
# {'_id': ObjectId('693a80a9dd56bb2de189e815'), 'category': '행거도어', 'product': '스파이더락 도어후크 8구, 화이트, 1개'}
# {'_id': ObjectId('693a80a9dd56bb2de189e816'), 'category': '행거도어', 'product': '선우랜드 우드볼 도어훅 6구, 화이트, 1개'}
# {'_id': ObjectId('693a80a9dd56bb2de189e817'), 'category': '행거도어', 'product': '코멧 홈 우드볼 도어행거, 10구, 혼합색상'}
# {'_id': ObjectId('693a80a9dd56bb2de189e818'), 'category': '매트리스커버', 'product': '보드래 헬로우 누빔 매트리스커버, 핑크'}
# {'_id': ObjectId('693a80a9dd56bb2de189e819'), 'category': '매트리스커버', 'product': '보몽드 순면스퀘어 솔리드 누빔매트커버, 아이보리'}
# {'_id': ObjectId('693a80a9dd56bb2de189e81a'), 'category': '매트리스커버', 'product': '더자리 에코항균 마이크로 매트리스커버, 밀키핑크'}
# {'_id': ObjectId('693a80a9dd56bb2de189e81b'), 'category': '매트리스커버', 'product': '타카타카 프리미엄 나노 화이바 누빔 매트리스 커버, 미스밍고'}
# {'_id': ObjectId('693a80a9dd56bb2de189e81c'), 'category': '매트리스커버', 'product': '네이쳐리빙 피아블 클래식 방수 매트리스커버, 그레이'}
# {'_id': ObjectId('693a80a9dd56bb2de189e81d'), 'category': '매트리스커버', 'product': '프로텍트어베드 베이직 매트리스 방수커버, 그레이'}

# %% [markdown]
# ### 연습문제를 위한 사전 준비

# %% [markdown]
# <div class="alert alert-block" style="border: 2px solid #1565C0;background-color:#E3F2FD;padding:10px">
# <font size="3em" style="color:#0D47A1;">연습문제: 'category' 필드에 있는 모든 카테고리 종류를 조회하세요</font><br>
# </div>

# %%
categories = collection.distinct("category")
categories
# Out:
# ['매트리스커버', '여름이불세트', '행거도어']

# %% [markdown]
# <div class="alert alert-block" style="border: 2px solid #1565C0;background-color:#E3F2FD;padding:10px">
# <font size="3em" style="color:#0D47A1;">연습문제: 모든 상품(product)을 조회하세요</font><br>
# </div>

# %%
products = collection.find({}, {"_id": 0, "product": 1})  # _id 제외, product만 가져오기
product_list = []

for product_document in products:
    print(product_document['product'])  # 각 문서에서 product 값 출력
    product_list.append(product_document['product'])  # 리스트에 추가
# Out:
# 보몽드 순면스퀘어 솔리드 누빔매트커버, 다크블루
# 슈에뜨룸 선인장 리플 침구 세트, 베이지
# 선우랜드 레인보우 2단 문걸이용 옷걸이 _중형, 화이트, 상세페이지참조
# 보드래 헬로우 누빔 매트리스커버, 핑크
# 보드래 퍼펙트 누빔 매트리스커버, 차콜
# 피아블 클래식 방수 매트리스커버, 화이트
# 더자리 에코항균 마이크로 매트리스커버, 밀키차콜그레이
# 더자리 프레쉬 퓨어 매트리스 커버, 퓨어 차콜그레이
# 몽쉐어 알러스킨 항균 매트리스 커버, 카키그레이
# 쿠팡 브랜드 - 코멧 홈 40수 트윌 순면 100% 홑겹 매트리스커버, 그레이
# 패브릭아트 항균 마이크로 원단 매트리스 커버, 아이보리
# 바숨 순면 누빔 침대 매트리스커버, 차콜
# WEMAX 다용도 문옷걸이, 화이트, 1개
# 타카타카 프리미엄 나노 화이바 누빔 매트리스 커버, 젠틀핑핑
# 보몽드 순면스퀘어 누빔매트커버, 다크그레이
# 보드래 국내산 순면 60수 누빔 매트리스커버, 그레이
# 보드래 퍼펙트 누빔 매트리스커버, 베이지핑크
# 쿠팡 브랜드 - 코멧 홈 40수 순면 누빔 매트리스커버, 챠콜
# 바숨 순면 누빔 침대 매트리스커버, 화이트
# 프랑떼 항균 방수 매트리스커버, 화이트
# 보몽드 순면스퀘어 솔리드 누빔매트커버, 다크블루
# 네이쳐리빙 피아블 클래식 방수 매트리스커버, 그레이
# 쿠팡 브랜드 - 코멧 홈 순면 매트리스커버, 베이지
# 타카타카 프리미엄 나노 화이바 누빔 매트리스 커버, 프렌치불독
# 더자리 에코항균 마이크로 매트리스커버, 밀키그레이
# 보몽드 순면스퀘어 누빔매트커버, 화이트
# 피아블 클래식 방수 매트리스커버, 화이트
# 쿠팡 브랜드 - 코멧 홈 순면 매트리스커버, 차콜그레이
# 쉬즈홈 모던그리드 순면 여름이불 베개커버 패드세트, 핑크
# 스코홈 빅리플 여름 차렵이불패드 3종 세트, 마린그레이
# 아망떼 시어서커 리플 홑이불 패드세트, 웨이크
# 마이센스 무더운 여름엔 시어서커 여름이불 패드 베개 이불세트 30종, 시어서커_파스텔그레이
# 믹스앤매치 로라 프릴 시어서커 침구세트, 그레이
# 에피소드1 샤베트 프릴 시어서커 여름이불패드세트, 그레이
# 슈에뜨룸 선인장 리플 침구 세트, 베이지
# 아망떼 시어서커 리플 홑이불 패드세트, 허브티
# 지베딩 아이스베어 시어서커 여름침구 풀세트, 민트그레이
# 쁘리엘르 테스 시어서커 여름이불 패드세트, 그레이
# 쉬즈홈 시어서커 홑이불 + 토퍼 + 베개커버 세트, 나나 옐로우
# 아망떼 시어서커 리플 퀼팅 이불패드세트, 리엔나
# 바자르 트로피컬 인견 여름 이불세트 인견이불 + 베개커버 2p + 인견패드, 그린
# 바자르 라이닝 혼방 인견 여름 이불베개세트 + 패드 Q, 쿨 네이비
# 슈에뜨룸 비숑 피치스킨 침구세트, 그레이
# 스코홈 시어서커 여름 이불 패드 3종 세트, 차콜
# 스코홈 어번시리즈 순면 차렵이불 누빔 매트커버세트 S 차콜
# 쉬즈홈 루즈 시어서커 차렵이불 패드세트, 그레이
# 예가로드 메리엘 시어서커 누비이불 패드세트, 블루
# 에피소드1 샤베트 프릴 시어서커 여름이불패드세트, 화이트
# 쉬즈홈 플루 시어서커 차렵이불 패드세트, 그린
# 메종 레이스 차렵 이불 세트, 블루
# 믹스앤매치 로라 프릴 시어서커 침구세트, 그린
# 슈에뜨룸 발그레 피치 리플 침구 세트, 혼합 색상
# 보몽드 메종 레이스 차렵이불 3종 세트, 민트
# 슈에뜨룸 체크 피치스킨 침구세트, 모카
# 메리엘 시어서커 에어리플 이불세트, 그레이
# 슈에뜨룸 빠삐용 시어서커 침구세트, 네이비
# 믹스앤매치 에이프릴 리플 누비이불 패드세트, 화이트
# 쉬즈홈 시어서커 홑이불 토퍼세트, 루즈 그레이
# 이코디 5단 엔틱 도어 행거, 브라운, 1개
# 선우랜드 우드볼 도어훅 4구, 실버, 1개
# 리은상점 다용도 도어훅 문걸이 행거 모자걸이 머플러 목도리 걸이, 화이트, 5개
# 퍼니스코 다용도걸이 모자걸이 가방걸이 도어훅 도어행거 문걸이, 엔틱브라운, 1세트
# 스텐 도어후크 옷걸이/도어훅 문옷걸이 행거 바지걸이, 혼합 색상, 1개
# 디비플러스 키펙스 컬러 폭조절 오버 도어훅, 블랙, 1개
# 리빙스토리 1+1 문에 거는 문 옷걸이 음자리 도어후크 방문 행거, 음자리도어후크-로즈골드, 2개
# 나이스후크 도어행거 2개 세트 (문행거), 블랙+화이트
# 리빙파이 도어훅 옷걸이 행거 7구, 블랙, 1개
# 선우랜드 우드볼 도어훅 10구, 실버, 1개
# 웰렉스 도어행거 MH1060 신형 본사직발송 미니건조대 도어옷걸이 도어훅, 고동색, 1개
# 엔비 엔틱 7구 도어훅 옷걸이, 도어훅 1+1, 1+1
# 코시나 무타공 문걸이 후크선반 1단, 화이트, 1개
# 코시나 무타공 올스텐 문걸이행거, 혼합 색상, 1개
# [아트박스 POOM/이케아] ENUDDEN 도어 행거, 본품, 수량
# 비스비바 우드 폴 다용도걸이 3구, 혼합 색상, 1개
# 숲속애 웨이브 도어후크 5구, 블랙, 1개
# 펀타스틱 다용도 문틀걸이, 화이트, 1개
# 선우랜드 우드볼 도어훅 4구, 화이트, 1개
# 네이쳐리빙 어반모카 와이어 도어훅 옷걸이 6구, 단일 색상, 1개
# 까사마루 블랑 접이식 문걸이 건조대, 1개
# 선우랜드 우드볼 도어훅 6구, 실버, 1개
# 이케아 ENUDDEN 문걸이 행거 402.516.66, 화이트, 1개
# 선우랜드 우드볼 도어훅 10구, 화이트, 1개
# 코멧 홈 우드볼 도어행거, 6구, 혼합색상
# 선우랜드 레인보우 2단 문걸이용 옷걸이 _중형, 화이트, 상세페이지참조
# 코시나 무타공 문걸이 후크선반 2단, 화이트, 1개
# 스파이더락 도어후크 8구, 화이트, 1개
# 선우랜드 우드볼 도어훅 6구, 화이트, 1개
# 코멧 홈 우드볼 도어행거, 10구, 혼합색상
# 보드래 헬로우 누빔 매트리스커버, 핑크
# 보몽드 순면스퀘어 솔리드 누빔매트커버, 아이보리
# 더자리 에코항균 마이크로 매트리스커버, 밀키핑크
# 타카타카 프리미엄 나노 화이바 누빔 매트리스 커버, 미스밍고
# 네이쳐리빙 피아블 클래식 방수 매트리스커버, 그레이
# 프로텍트어베드 베이직 매트리스 방수커버, 그레이

# %%
import pandas as pd
products = collection.find()
df_product= pd.DataFrame(products)
df_product
# Out:
#                          _id category                                  product
# 0   693a80a7dd56bb2de189e7c0   매트리스커버               보몽드 순면스퀘어 솔리드 누빔매트커버, 다크블루
# 1   693a80a7dd56bb2de189e7c1   여름이불세트                   슈에뜨룸 선인장 리플 침구 세트, 베이지
# 2   693a80a7dd56bb2de189e7c2     행거도어  선우랜드 레인보우 2단 문걸이용 옷걸이 _중형, 화이트, 상세페이지참조
# 3   693a80a7dd56bb2de189e7c3   매트리스커버                    보드래 헬로우 누빔 매트리스커버, 핑크
# 4   693a80a7dd56bb2de189e7c4   매트리스커버                    보드래 퍼펙트 누빔 매트리스커버, 차콜
# ..                       ...      ...                                      ...
# 89  693a80a9dd56bb2de189e819   매트리스커버               보몽드 순면스퀘어 솔리드 누빔매트커버, 아이보리
# 90  693a80a9dd56bb2de189e81a   매트리스커버               더자리 에코항균 마이크로 매트리스커버, 밀키핑크
# 91  693a80a9dd56bb2de189e81b   매트리스커버        타카타카 프리미엄 나노 화이바 누빔 매트리스 커버, 미스밍고
# 92  693a80a9dd56bb2de189e81c   매트리스커버             네이쳐리빙 피아블 클래식 방수 매트리스커버, 그레이
# 93  693a80a9dd56bb2de189e81d   매트리스커버               프로텍트어베드 베이직 매트리스 방수커버, 그레이
#
# [94 rows x 3 columns]

# %% [markdown]
# <div class="alert alert-block" style="border: 2px solid #1565C0;background-color:#E3F2FD;padding:10px">
# <font size="3em" style="color:#0D47A1;">연습문제: "매트리스커버" 카테고리의 모든 상품을 조회하세요<br> (find 와 aggregation 을 사용한 코드를 각각 작성해주세요)</font><br>
# </div>

# %%
pd.DataFrame(collection.find({'category': "매트리스커버"}))['product'].to_list()
# Out:
# ['보몽드 순면스퀘어 솔리드 누빔매트커버, 다크블루',
#  '보드래 헬로우 누빔 매트리스커버, 핑크',
#  '보드래 퍼펙트 누빔 매트리스커버, 차콜',
#  '피아블 클래식 방수 매트리스커버, 화이트',
#  '더자리 에코항균 마이크로 매트리스커버, 밀키차콜그레이',
#  '더자리 프레쉬 퓨어 매트리스 커버, 퓨어 차콜그레이',
#  '몽쉐어 알러스킨 항균 매트리스 커버, 카키그레이',
#  '쿠팡 브랜드 - 코멧 홈 40수 트윌 순면 100% 홑겹 매트리스커버, 그레이',
#  '패브릭아트 항균 마이크로 원단 매트리스 커버, 아이보리',
#  '바숨 순면 누빔 침대 매트리스커버, 차콜',
#  '타카타카 프리미엄 나노 화이바 누빔 매트리스 커버, 젠틀핑핑',
#  '보몽드 순면스퀘어 누빔매트커버, 다크그레이',
#  '보드래 국내산 순면 60수 누빔 매트리스커버, 그레이',
#  '보드래 퍼펙트 누빔 매트리스커버, 베이지핑크',
#  '쿠팡 브랜드 - 코멧 홈 40수 순면 누빔 매트리스커버, 챠콜',
#  '바숨 순면 누빔 침대 매트리스커버, 화이트',
#  '프랑떼 항균 방수 매트리스커버, 화이트',
#  '보몽드 순면스퀘어 솔리드 누빔매트커버, 다크블루',
#  '네이쳐리빙 피아블 클래식 방수 매트리스커버, 그레이',
#  '쿠팡 브랜드 - 코멧 홈 순면 매트리스커버, 베이지',
#  '타카타카 프리미엄 나노 화이바 누빔 매트리스 커버, 프렌치불독',
#  '더자리 에코항균 마이크로 매트리스커버, 밀키그레이',
#  '보몽드 순면스퀘어 누빔매트커버, 화이트',
#  '피아블 클래식 방수 매트리스커버, 화이트',
#  '쿠팡 브랜드 - 코멧 홈 순면 매트리스커버, 차콜그레이',
#  '보드래 헬로우 누빔 매트리스커버, 핑크',
#  '보몽드 순면스퀘어 솔리드 누빔매트커버, 아이보리',
#  '더자리 에코항균 마이크로 매트리스커버, 밀키핑크',
#  '타카타카 프리미엄 나노 화이바 누빔 매트리스 커버, 미스밍고',
#  '네이쳐리빙 피아블 클래식 방수 매트리스커버, 그레이',
#  '프로텍트어베드 베이직 매트리스 방수커버, 그레이']

# %%
## product 컬럼만 추출
for product in collection.find({"category":"매트리스커버"}, {"_id":0,"product":1}):
    print(product)
# Out:
# {'product': '보몽드 순면스퀘어 솔리드 누빔매트커버, 다크블루'}
# {'product': '보드래 헬로우 누빔 매트리스커버, 핑크'}
# {'product': '보드래 퍼펙트 누빔 매트리스커버, 차콜'}
# {'product': '피아블 클래식 방수 매트리스커버, 화이트'}
# {'product': '더자리 에코항균 마이크로 매트리스커버, 밀키차콜그레이'}
# {'product': '더자리 프레쉬 퓨어 매트리스 커버, 퓨어 차콜그레이'}
# {'product': '몽쉐어 알러스킨 항균 매트리스 커버, 카키그레이'}
# {'product': '쿠팡 브랜드 - 코멧 홈 40수 트윌 순면 100% 홑겹 매트리스커버, 그레이'}
# {'product': '패브릭아트 항균 마이크로 원단 매트리스 커버, 아이보리'}
# {'product': '바숨 순면 누빔 침대 매트리스커버, 차콜'}
# {'product': '타카타카 프리미엄 나노 화이바 누빔 매트리스 커버, 젠틀핑핑'}
# {'product': '보몽드 순면스퀘어 누빔매트커버, 다크그레이'}
# {'product': '보드래 국내산 순면 60수 누빔 매트리스커버, 그레이'}
# {'product': '보드래 퍼펙트 누빔 매트리스커버, 베이지핑크'}
# {'product': '쿠팡 브랜드 - 코멧 홈 40수 순면 누빔 매트리스커버, 챠콜'}
# {'product': '바숨 순면 누빔 침대 매트리스커버, 화이트'}
# {'product': '프랑떼 항균 방수 매트리스커버, 화이트'}
# {'product': '보몽드 순면스퀘어 솔리드 누빔매트커버, 다크블루'}
# {'product': '네이쳐리빙 피아블 클래식 방수 매트리스커버, 그레이'}
# {'product': '쿠팡 브랜드 - 코멧 홈 순면 매트리스커버, 베이지'}
# {'product': '타카타카 프리미엄 나노 화이바 누빔 매트리스 커버, 프렌치불독'}
# {'product': '더자리 에코항균 마이크로 매트리스커버, 밀키그레이'}
# {'product': '보몽드 순면스퀘어 누빔매트커버, 화이트'}
# {'product': '피아블 클래식 방수 매트리스커버, 화이트'}
# {'product': '쿠팡 브랜드 - 코멧 홈 순면 매트리스커버, 차콜그레이'}
# {'product': '보드래 헬로우 누빔 매트리스커버, 핑크'}
# {'product': '보몽드 순면스퀘어 솔리드 누빔매트커버, 아이보리'}
# {'product': '더자리 에코항균 마이크로 매트리스커버, 밀키핑크'}
# {'product': '타카타카 프리미엄 나노 화이바 누빔 매트리스 커버, 미스밍고'}
# {'product': '네이쳐리빙 피아블 클래식 방수 매트리스커버, 그레이'}
# {'product': '프로텍트어베드 베이직 매트리스 방수커버, 그레이'}

# %% [markdown]
# <div class="alert alert-block" style="border: 2px solid #1565C0;background-color:#E3F2FD;padding:10px">
# <font size="3em" style="color:#0D47A1;">연습문제: 각 카테고리별 상품 수를 조회하세요. 이를 위해 MongoDB의 aggregation 기능을 사용하세요</font><br>
# </div>

# %%
## aggregotion 으로 pipeline 이용
pipeline = [
    {"#match":{"category": "매트리스커버"}}, #매트리스커버 카테고리만 추출
    {"$project": {"_id":0, "product": 1}}
]
product_list = list(collection.aggregate(pipeline))
product_list
# Out:
# ---------------------------------------------------------------------------
# OperationFailure                          Traceback (most recent call last)
# Cell In[40], line 6
#       1 ## aggregotion 으로 pipeline 이용
#       2 pipeline = [
#       3     {"#match":{"category": "매트리스커버"}}, #매트리스커버 카테고리만 추출
#       4     {"$project": {"_id":0, "product": 1}}
#       5 ]
# ----> 6 product_list = list(collection.aggregate(pipeline))
#       7 product_list
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\pymongo\synchronous\collection.py:3015, in Collection.aggregate(self, pipeline, session, let, comment, **kwargs)
#    2929 """Perform an aggregation using the aggregation framework on this
#    2930 collection.
#    2931
#    (...)   3012     https://mongodb.com/docs/manual/reference/command/aggregate
#    3013 """
#    3014 with self._database.client._tmp_session(session, close=False) as s:
# -> 3015     return self._aggregate(
#    3016         _CollectionAggregationCommand,
#    3017         pipeline,
#    3018         CommandCursor,
#    3019         session=s,
#    3020         explicit_session=session is not None,
#    3021         let=let,
#    3022         comment=comment,
#    3023         **kwargs,
#    3024     )
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\pymongo\_csot.py:125, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     123         with _TimeoutContext(timeout):
#     124             return func(self, *args, **kwargs)
# --> 125 return func(self, *args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\pymongo\synchronous\collection.py:2913, in Collection._aggregate(self, aggregation_command, pipeline, cursor_class, session, explicit_session, let, comment, **kwargs)
#    2902     kwargs["comment"] = comment
#    2903 cmd = aggregation_command(
#    2904     self,
#    2905     cursor_class,
#    (...)   2910     user_fields={"cursor": {"firstBatch": 1}},
#    2911 )
# -> 2913 return self._database.client._retryable_read(
#    2914     cmd.get_cursor,
#    2915     cmd.get_read_preference(session),  # type: ignore[arg-type]
#    2916     session,
#    2917     retryable=not cmd._performs_write,
#    2918     operation=_Op.AGGREGATE,
#    2919 )
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\pymongo\synchronous\mongo_client.py:2047, in MongoClient._retryable_read(self, func, read_pref, session, operation, address, retryable, operation_id)
#    2042 # Ensure that the client supports retrying on reads and there is no session in
#    2043 # transaction, otherwise, we will not support retry behavior for this call.
#    2044 retryable = bool(
#    2045     retryable and self.options.retry_reads and not (session and session.in_transaction)
#    2046 )
# -> 2047 return self._retry_internal(
#    2048     func,
#    2049     session,
#    2050     None,
#    2051     operation,
#    2052     is_read=True,
#    2053     address=address,
#    2054     read_pref=read_pref,
#    2055     retryable=retryable,
#    2056     operation_id=operation_id,
#    2057 )
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\pymongo\_csot.py:125, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     123         with _TimeoutContext(timeout):
#     124             return func(self, *args, **kwargs)
# --> 125 return func(self, *args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\pymongo\synchronous\mongo_client.py:2014, in MongoClient._retry_internal(self, func, session, bulk, operation, is_read, address, read_pref, retryable, operation_id)
#    1977 @_csot.apply
#    1978 def _retry_internal(
#    1979     self,
#    (...)   1988     operation_id: Optional[int] = None,
#    1989 ) -> T:
#    1990     """Internal retryable helper for all client transactions.
#    1991
#    1992     :param func: Callback function we want to retry
#    (...)   2001     :return: Output of the calling func()
#    2002     """
#    2003     return _ClientConnectionRetryable(
#    2004         mongo_client=self,
#    2005         func=func,
#    2006         bulk=bulk,
#    2007         operation=operation,
#    2008         is_read=is_read,
#    2009         session=session,
#    2010         read_pref=read_pref,
#    2011         address=address,
#    2012         retryable=retryable,
#    2013         operation_id=operation_id,
# -> 2014     ).run()
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\pymongo\synchronous\mongo_client.py:2765, in _ClientConnectionRetryable.run(self)
#    2763 self._check_last_error(check_csot=True)
#    2764 try:
# -> 2765     return self._read() if self._is_read else self._write()
#    2766 except ServerSelectionTimeoutError:
#    2767     # The application may think the write was never attempted
#    2768     # if we raise ServerSelectionTimeoutError on the retry
#    2769     # attempt. Raise the original exception instead.
#    2770     self._check_last_error()
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\pymongo\synchronous\mongo_client.py:2926, in _ClientConnectionRetryable._read(self)
#    2918 if self._retrying:
#    2919     _debug_log(
#    2920         _COMMAND_LOGGER,
#    2921         message=f"Retrying read attempt number {self._attempt_number}",
#    (...)   2924         operationId=self._operation_id,
#    2925     )
# -> 2926 return self._func(self._session, self._server, conn, read_pref)
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\pymongo\synchronous\aggregation.py:164, in _AggregationCommand.get_cursor(self, session, server, conn, read_preference)
#     161     write_concern = None
#     163 # Run command.
# --> 164 result = conn.command(
#     165     self._database.name,
#     166     cmd,
#     167     read_preference,
#     168     self._target.codec_options,
#     169     parse_write_concern_error=True,
#     170     read_concern=read_concern,
#     171     write_concern=write_concern,
#     172     collation=self._collation,
#     173     session=session,
#     174     client=self._database.client,
#     175     user_fields=self._user_fields,
#     176 )
#     178 if self._result_processor:
#     179     self._result_processor(result, conn)
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\pymongo\synchronous\helpers.py:47, in _handle_reauth.<locals>.inner(*args, **kwargs)
#      44 from pymongo.synchronous.pool import Connection
#      46 try:
# ---> 47     return func(*args, **kwargs)
#      48 except OperationFailure as exc:
#      49     if no_reauth:
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\pymongo\synchronous\pool.py:413, in Connection.command(self, dbname, spec, read_preference, codec_options, check, allowable_errors, read_concern, write_concern, parse_write_concern_error, collation, session, client, retryable_write, publish_events, user_fields, exhaust_allowed)
#     411     self._raise_if_not_writable(unacknowledged)
#     412 try:
# --> 413     return command(
#     414         self,
#     415         dbname,
#     416         spec,
#     417         self.is_mongos,
#     418         read_preference,
#     419         codec_options,  # type: ignore[arg-type]
#     420         session,
#     421         client,
#     422         check,
#     423         allowable_errors,
#     424         self.address,
#     425         listeners,
#     426         self.max_bson_size,
#     427         read_concern,
#     428         parse_write_concern_error=parse_write_concern_error,
#     429         collation=collation,
#     430         compression_ctx=self.compression_context,
#     431         use_op_msg=self.op_msg_enabled,
#     432         unacknowledged=unacknowledged,
#     433         user_fields=user_fields,
#     434         exhaust_allowed=exhaust_allowed,
#     435         write_concern=write_concern,
#     436     )
#     437 except (OperationFailure, NotPrimaryError):
#     438     raise
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\pymongo\synchronous\network.py:212, in command(conn, dbname, spec, is_mongos, read_preference, codec_options, session, client, check, allowable_errors, address, listeners, max_bson_size, read_concern, parse_write_concern_error, collation, compression_ctx, use_op_msg, unacknowledged, user_fields, exhaust_allowed, write_concern)
#     210             client._process_response(response_doc, session)
#     211         if check:
# --> 212             helpers_shared._check_command_response(
#     213                 response_doc,
#     214                 conn.max_wire_version,
#     215                 allowable_errors,
#     216                 parse_write_concern_error=parse_write_concern_error,
#     217             )
#     218 except Exception as exc:
#     219     duration = datetime.datetime.now() - start
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\pymongo\helpers_shared.py:284, in _check_command_response(response, max_wire_version, allowable_errors, parse_write_concern_error, pool_opts)
#     281 elif code == 43:
#     282     raise CursorNotFound(errmsg, code, response, max_wire_version)
# --> 284 raise OperationFailure(errmsg, code, response, max_wire_version)
#
# OperationFailure: Unrecognized pipeline stage name: '#match', full error: {'ok': 0.0, 'errmsg': "Unrecognized pipeline stage name: '#match'", 'code': 40324, 'codeName': 'Location40324'}

# %% [markdown]
# <div class="alert alert-block" style="border: 2px solid #1565C0;background-color:#E3F2FD;padding:10px">
# <font size="3em" style="color:#0D47A1;">연습문제: 상품명(product)에 '핑크'가 포함된 모든 상품을 조회하세요</font><br>
# </div>

# %% [markdown]
# <div class="alert alert-block" style="border: 2px solid #1565C0;background-color:#E3F2FD;padding:10px">
# <font size="3em" style="color:#0D47A1;">연습문제: '매트리스커버' 카테고리의 상품 중, 상품명에 '차콜'이 포함된 상품을 조회하세요</font><br>
# </div>

# %% [markdown]
# <div class="alert alert-block" style="border: 2px solid #1565C0;background-color:#E3F2FD;padding:10px">
# <font size="3em" style="color:#0D47A1;">연습문제: 'product' 필드에 대한 텍스트 인덱스를 생성하세요</font><br>
# </div>

# %% [markdown]
# <div class="alert alert-block" style="border: 2px solid #1565C0;background-color:#E3F2FD;padding:10px">
# <font size="3em" style="color:#0D47A1;">연습문제: 'product' 필드에서 '누빔'이라는 단어를 포함하는 모든 문서를 텍스트 검색을 이용해 찾으세요<br> (find 와 aggregation 을 사용한 코드를 각각 작성해주세요)</font><br>
# </div>
