# %% [markdown]
# # Pandas의 시각화 기능

# %% [markdown]
# Pandas의 시리즈나 데이터프레임은 `plot`이라는 시각화 메서드를 내장하고 있다. `plot`은 matplotlib를 내부에서 임포트하여 사용한다.

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
plt.rcParams['font.family'] = ['Malgun Gothic']
plt.rcParams['axes.unicode_minus'] =False
import numpy as np
import matplotlib.pyplot as plt

# %%
np.random.seed(0)
df1 = pd.DataFrame(np.random.randn(10000, 3),
                   index=pd.date_range('1/1/2026', periods=10000),
                   columns=['A', 'B', 'C'])
df1
# Out:
#                    A         B         C
# 2026-01-01  1.764052  0.400157  0.978738
# 2026-01-02  2.240893  1.867558 -0.977278
# 2026-01-03  0.950088 -0.151357 -0.103219
# 2026-01-04  0.410599  0.144044  1.454274
# 2026-01-05  0.761038  0.121675  0.443863
# ...              ...       ...       ...
# 2053-05-14 -0.303895  0.213129  0.046172
# 2053-05-15  1.533356  1.910297  0.069245
# 2053-05-16  1.039309  0.118204 -0.762623
# 2053-05-17  0.606083 -0.400898 -0.585452
# 2053-05-18 -1.511276  0.976844  1.255501
#
# [10000 rows x 3 columns]

# %%
df_cumsum = df1.cumsum()
df_cumsum
# Out:
#                     A         B          C
# 2026-01-01   1.764052  0.400157   0.978738
# 2026-01-02   4.004946  2.267715   0.001460
# 2026-01-03   4.955034  2.116358  -0.101759
# 2026-01-04   5.365632  2.260402   1.352515
# 2026-01-05   6.126670  2.382077   1.796378
# ...               ...       ...        ...
# 2053-05-14 -76.326279 -6.156591 -52.851278
# 2053-05-15 -74.792923 -4.246294 -52.782033
# 2053-05-16 -73.753614 -4.128090 -53.544656
# 2053-05-17 -73.147531 -4.528988 -54.130108
# 2053-05-18 -74.658807 -3.552144 -52.874607
#
# [10000 rows x 3 columns]

# %%
plt.figure(figsize=(10,2))
df_cumsum.plot()
# Out:
# <Axes: >

# %%
np.random.randn(100,3)
# Out:
# array([[-1.30652685,  1.65813068, -0.11816405],
#        [-0.6801782 ,  0.66638308, -0.46071979],
#        [-1.33425847, -1.34671751,  0.69377315],
#        [-0.15957344, -0.13370156,  1.07774381],
#        [-1.12682581, -0.73067775, -0.38487981],
#        [ 0.09435159, -0.04217145, -0.28688719],
#        [-0.0616264 , -0.10730528, -0.71960439],
#        [-0.81299299,  0.27451636, -0.89091508],
#        [-1.15735526, -0.31229225, -0.15766702],
#        [ 2.2567235 , -0.70470028,  0.94326072],
#        [ 0.74718833, -1.18894496,  0.77325298],
#        [-1.18388064, -2.65917224,  0.60631952],
#        [-1.75589058,  0.45093446, -0.6840109 ],
#        [ 1.6595508 ,  1.0685094 , -0.4533858 ],
#        [-0.68783761, -1.2140774 , -0.44092263],
#        [-0.2803555 , -0.36469354,  0.15670386],
#        [ 0.5785215 ,  0.34965446, -0.76414392],
#        [-1.43779147,  1.36453185, -0.68944918],
#        [-0.6522936 , -0.52118931, -1.84306955],
#        [-0.477974  , -0.47965581,  0.6203583 ],
#        [ 0.69845715,  0.00377089,  0.93184837],
#        [ 0.33996498, -0.01568211,  0.16092817],
#        [-0.19065349, -0.39484951, -0.26773354],
#        [-1.12801133,  0.28044171, -0.99312361],
#        [ 0.84163126, -0.24945858,  0.04949498],
#        [ 0.49383678,  0.64331447, -1.57062341],
#        [-0.20690368,  0.88017891, -1.69810582],
#        [ 0.38728048, -2.25556423, -1.02250684],
#        [ 0.03863055, -1.6567151 , -0.98551074],
#        [-1.47183501,  1.64813493,  0.16422776],
#        [ 0.56729028, -0.2226751 , -0.35343175],
#        [-1.61647419, -0.29183736, -0.76149221],
#        [ 0.85792392,  1.14110187,  1.46657872],
#        [ 0.85255194, -0.59865394, -1.11589699],
#        [ 0.76666318,  0.35629282, -1.76853845],
#        [ 0.35548179,  0.81451982,  0.05892559],
#        [-0.18505367, -0.80764849, -1.4465347 ],
#        [ 0.80029795, -0.30911444, -0.23346666],
#        [ 1.73272119,  0.68450111,  0.370825  ],
#        [ 0.14206181,  1.51999486,  1.71958931],
#        [ 0.92950511,  0.58222459, -2.09460307],
#        [ 0.12372191, -0.13010695,  0.09395323],
#        [ 0.94304609, -2.73967717, -0.56931205],
#        [ 0.26990435, -0.46684555, -1.41690611],
#        [ 0.86896349,  0.27687191, -0.97110457],
#        [ 0.3148172 ,  0.82158571,  0.00529265],
#        [ 0.8005648 ,  0.07826018, -0.39522898],
#        [-1.15942052, -0.08593077,  0.19429294],
#        [ 0.87583276, -0.11510747,  0.45741561],
#        [-0.96461201, -0.78262916, -0.1103893 ],
#        [-1.05462846,  0.82024784,  0.46313033],
#        [ 0.27909576,  0.33890413,  2.02104356],
#        [-0.46886419, -2.20144129,  0.1993002 ],
#        [-0.05060354, -0.51751904, -0.97882986],
#        [-0.43918952,  0.18133843, -0.5028167 ],
#        [ 2.41245368, -0.96050438, -0.79311736],
#        [-2.28862004,  0.25148442, -2.01640663],
#        [-0.53945463, -0.27567053, -0.70972797],
#        [ 1.73887268,  0.99439439,  1.31913688],
#        [-0.88241882,  1.12859406,  0.49600095],
#        [ 0.77140595,  1.02943883, -0.90876325],
#        [-0.42431762,  0.86259601, -2.65561909],
#        [ 1.51332808,  0.55313206, -0.04570396],
#        [ 0.22050766, -1.02993528, -0.34994336],
#        [ 1.10028434,  1.29802197,  2.69622405],
#        [-0.07392467, -0.65855297, -0.51423397],
#        [-1.01804188, -0.07785476,  0.38273243],
#        [-0.03424228,  1.09634685, -0.2342158 ],
#        [-0.34745065, -0.58126848, -1.63263453],
#        [-1.56776772, -1.17915793,  1.30142807],
#        [ 0.89526027,  1.37496407, -1.33221165],
#        [-1.96862469, -0.66005632,  0.17581895],
#        [ 0.49869027,  1.04797216,  0.28427967],
#        [ 1.74266878, -0.22260568, -0.91307922],
#        [-1.68121822, -0.88897136,  0.24211796],
#        [-0.88872026,  0.93674246,  1.41232771],
#        [-2.36958691,  0.8640523 , -2.23960406],
#        [ 0.40149906,  1.22487056,  0.06485611],
#        [-1.27968917, -0.5854312 , -0.26164545],
#        [-0.18224478, -0.20289684, -0.10988278],
#        [ 0.21348005, -1.20857365, -0.24201983],
#        [ 1.51826117, -0.38464542, -0.44383609],
#        [ 1.0781973 , -2.55918467,  1.1813786 ],
#        [-0.63190376,  0.16392857,  0.09632136],
#        [ 0.94246812, -0.26759475, -0.67802578],
#        [ 1.29784579, -2.36417382,  0.02033418],
#        [-1.34792542, -0.76157339,  2.01125668],
#        [-0.04459543,  0.1950697 , -1.78156286],
#        [-0.72904466,  0.1965574 ,  0.35475769],
#        [ 0.61688655,  0.0086279 ,  0.52700421],
#        [ 0.45378191, -1.82974041,  0.03700572],
#        [ 0.76790241,  0.58987982, -0.36385881],
#        [-0.80562651, -1.11831192, -0.13105401],
#        [ 1.13307988, -1.9518041 , -0.65989173],
#        [-1.13980246,  0.78495752, -0.55430963],
#        [-0.47063766, -0.21694957,  0.44539325],
#        [-0.392389  , -3.04614305,  0.54331189],
#        [ 0.43904296, -0.21954103, -1.08403662],
#        [ 0.35178011,  0.37923553, -0.47003288],
#        [-0.21673147, -0.9301565 , -0.17858909]])

# %%
import seaborn as sns
iris = sns.load_dataset("iris")    # 붓꽃 데이터
titanic = sns.load_dataset("titanic")    # 타이타닉호 데이터

# %%
iris[:10].plot(figsize=(10,3), kind='bar')
# Out:
# <Axes: >

# %%
iris[:5].plot.bar(rot=0)
plt.title("Iris 데이터의 Bar Plot")
plt.xlabel("Data")
plt.ylabel("각 Feature의 값")
plt.ylim(0, 7)
plt.show()

# %% [markdown]
# `plot` 메서드의 `kind`라는 인수를 바꾸면 여러가지 플롯을 그릴 수 있다. 다음과 같은 인수값을 지원한다.
#
# * `bar`
# * `pie`
# * `hist`
# * `kde`
# * `box`
# * `scatter`
# * `area`

# %% [markdown]
# `kind` 인수에 문자열을 쓰는 대신 `plot.bar`처럼 직접 메서드로 사용할 수도 있다.

# %% [markdown]
# 다음은 그룹분석으로 각 붓꽃종의 특징값의 평균을 구한 것이다.

# %% [markdown]
# 그룹분석 결과도 데이터프레임이므로 같은 방식으로 시각화할 수 있다.

# %% [markdown]
# 전치연산으로 시각화 방법을 다르게 할 수도 있다.

# %% [markdown]
# 다음은 ``pie``,  ``hist``, ``kde``, ``box``, ``scatter`` 플롯 예제이다.

# %% [markdown]
# 박스플롯에 대해서는 추가적인 기능을 가진 `boxplot` 명령이 별도로 있다.
